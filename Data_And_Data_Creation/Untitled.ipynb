# %%
import pandas as pd
summed_by_date = pd.read_csv('expanded_dummied_welcome_table_summed.csv')

# %%
summed_by_date["yesterday_visits_per_hour"] = pd.Series([None]+list(summed_by_date.avg_visits_per_hour))

# %%
summed_by_date.columns
# Out:
# Index([u'Unnamed: 0', u'Unnamed: 0.1', u'total_visitors', u'total_returns',
#        u'total_new', u'Temperature', u'from_11201', u'avg_visits_per_hour',
#        u'avg_returns_per_hour', u'avg_new_per_hour',
#        u'avg_from_11201_per_hour', u'ratio_11201', u'day', u'month', u'year',
#        u'given_temp', u'precipitation', u'cloud_cover', u'snow', u'rain',
#        u'year_2015', u'year_2016', u'year_2017', u'day_1', u'day_2', u'day_3',
#        u'day_4', u'day_5', u'day_6', u'month_2', u'month_3', u'month_4',
#        u'month_5', u'month_6', u'month_7', u'month_8', u'month_9', u'month_10',
#        u'month_11', u'month_12', u'yesterday_visits_per_hour'],
#       dtype='object')

# %%
summed_by_date[['avg_visits_per_hour','yesterday_visits_per_hour']]
# Out:
#      avg_visits_per_hour  yesterday_visits_per_hour
# 0                   1.00                        NaN
# 1                  18.50                       1.00
# 2                  20.00                      18.50
# 3                  23.75                      20.00
# 4                  21.00                      23.75
# 5                   8.00                      21.00
# 6                  26.00                       8.00
# 7                  17.50                      26.00
# 8                  14.50                      17.50
# 9                  22.75                      14.50
# 10                 23.50                      22.75
# 11                 12.00                      23.50
# 12                 23.50                      12.00
# 13                 17.75                      23.50
# 14                 16.50                      17.75
# 15                 14.00                      16.50
# 16                 18.50                      14.00
# ...
