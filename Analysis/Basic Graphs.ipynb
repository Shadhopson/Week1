# %%
import pandas as pd
summed_by_date = pd.read_csv('../Data_And_Data_Creation/advanced_welcome_table_summed.csv')

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
summed_by_date.avg_from_11201_per_hour.argmax()
summed_by_date.columns
# Out:
# Index([u'total_visitors', u'total_returns', u'total_new', u'Temperature',
#        u'from_11201', u'avg_visits_per_hour', u'avg_returns_per_hour',
#        u'avg_new_per_hour', u'avg_from_11201_per_hour', u'ratio_11201', u'day',
#        u'month', u'year', u'given_temp', u'precipitation', u'cloud_cover',
#        u'snow', u'rain'],
#       dtype='object')

# %%
summed_by_date = summed_by_date.drop([108,71])

# %%
summed_by_date.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)

# %%
summed_by_date.set_index('Date', inplace=True)

# %%
grouped =  summed_by_date.groupby("day")

# %%
Tuesdays = grouped.get_group(1)
Thursdays =  grouped.get_group(3)
Saturdays = grouped.get_group(5)
Sundays = grouped.get_group(6)

# %%
summed_by_day_list = [Tuesdays, Thursdays, Saturdays, Sundays]
days = ["Tuesdays", "Thursdays", "Saturdays", "Sundays"]
items_checked = ['avg_visits_per_hour', 'avg_from_11201_per_hour', 'avg_new_per_hour', 'avg_returns_per_hour', 'ratio_11201']
item_names = ['Average Visitors Per Hour', 'Average Visitors From 11201 Per Hour', 'Average New Visitors Per Hour', "Average Returning Visitors Per Hour", "Ratio of 11201 to Total Visitors"]

# %%
count = 0
for item in items_checked:
    plt.figure(figsize=(9,3))
    ax = summed_by_date[item].plot(title= item_names[count] + " Over Time")
    ax.set_ylabel(item_names[count])
    idx = 0
    for day in summed_by_day_list:
        plt.figure(figsize=(9,3))
        ax = day[item].plot(title= item_names[count] + " Over Time On " + days[idx])
        ax.set_ylabel(item_names[count])
        idx += 1
    count += 1

# %% [markdown]
# # Average Visits Per Hour Over Time

# %%
plt.figure(figsize=(9,3))
ax = summed_by_date['avg_visits_per_hour'].plot(title="Average Visits Per Hour Over Time")
ax.set_ylabel("Average Visits Per Hour")
idx = 0
for day in summed_by_day_list:
    plt.figure(figsize=(9,3))
    ax = day['avg_visits_per_hour'].plot(title="Average Visits Per Hour Over Time On " + days[idx])
    ax.set_ylabel("Average Visits Per Hour")
    idx += 1

# %% [markdown]
# # Average Visits From 11201 Per Hour Over Time

# %%
plt.figure(figsize=(9,3))
ax = summed_by_date['avg_from_11201_per_hour'].plot(title="Average Visits From 11201 Over Time")
ax.set_ylabel("Average Visits From 11201 Per Hour")

idx = 0
for day in summed_by_day_list:
    plt.figure(figsize=(9,3))
    ax = day['avg_from_11201_per_hour'].plot(title="Average Visits From 11201 Over Time On " + days[idx])
    ax.set_ylabel("Average Visits From 11201")
    idx += 1

# %% [markdown]
# # Average New Visitors Per Hour

# %%
plt.figure(figsize=(9,3))
ax = summed_by_date['avg_new_per_hour'].plot(title="Average New Visitors Per Hour Over Time")
ax.set_ylabel("Average New Visitors Per Hour")

idx = 0
for day in summed_by_day_list:
    plt.figure(figsize=(9,3))
    ax = day['avg_new_per_hour'].plot(title="Average New Visitors Per Hour Over Time On " + days[idx])
    ax.set_ylabel("Average New Visitors Per Hour")
    idx += 1

# %% [markdown]
# # Average Returning Visitors Per Hour

# %%
plt.figure(figsize=(9,3))
ax = summed_by_date['avg_returns_per_hour'].plot(title = "Average Returning Visitors Per Hour Over Time")
ax.set_ylabel("Average Returning Visitors Per Hour")

idx = 0
for day in summed_by_day_list:
    plt.figure(figsize=(9,3))
    ax = day['avg_returns_per_hour'].plot(title="Average Returning Visitors Per Hour Over Time On " + days[idx])
    ax.set_ylabel("Average Returning Visitors Per Hour")
    idx += 1

# %% [markdown]
# # Ratio of 11201 visitors to total visitors in a day

# %%
plt.figure(figsize=(9,3))
ax = summed_by_date['ratio_11201'].plot(title = "Ratio of 11201 Visitors to Total Visitors in a Day")
ax.set_ylabel("Ratio of 11201 Visitors to Total Visitors")

idx = 0
for day in summed_by_day_list:
    plt.figure(figsize=(9,3))
    ax = day['ratio_11201'].plot(title="Ratio of 11201 Visitors to Total Visitors in a Day On " + days[idx])
    ax.set_ylabel("Ratio of 11201 Visitors to Total Visitors")
    idx += 1
