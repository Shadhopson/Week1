# %%
import pandas as pd

# %%
summed_by_date = pd.DataFrame.from_csv('advanced_welcome_table_summed.csv')

# %%
summed_by_date.head()
# Out:
#             total_visitors  total_returns  total_new  Temperature  from_11201  \
# 2015-08-20              37            0.0       37.0        81.37         NaN
# 2015-08-22              80            0.0       80.0        81.99         NaN
# 2015-08-23              95            3.0       92.0        79.89         NaN
# 2015-08-26              42            0.0       42.0        79.33         NaN
# 2015-08-28              16            0.0       16.0        81.34         NaN
#
#             visits_per_hour  returns_per_hour  new_per_hour  \
# 2015-08-20            18.50              0.00          18.5
# 2015-08-22            20.00              0.00          20.0
# 2015-08-23            23.75              0.75          23.0
# 2015-08-26            21.00              0.00          21.0
# 2015-08-28             8.00              0.00           8.0
#
#             from_11201_per_hour  day  month  year given_temp  precipitation  \
# ...

# %%
summed_by_date[['total_visitors', 'total_returns', 'total_new', 'from_11201','visits_per_hour', 'returns_per_hour','new_per_hour', 'from_11201_per_hour']].describe()
# Out:
#        total_visitors  total_returns   total_new  from_11201  visits_per_hour  \
# count      244.000000     244.000000  244.000000  181.000000       244.000000
# mean        60.807377      19.393443   41.290984   25.392265        18.976434
# std         41.356821      12.214177   37.109134   14.744707         9.776815
# min          2.000000       0.000000    0.000000    0.000000         1.000000
# 25%         29.000000      10.000000   11.000000         NaN        12.500000
# 50%         52.500000      18.000000   35.500000         NaN        18.750000
# 75%         84.250000      27.000000   62.500000         NaN        24.125000
# max        362.000000      82.000000  333.000000  100.000000        90.500000
#
#        returns_per_hour  new_per_hour  from_11201_per_hour
# count        244.000000    244.000000           181.000000
# mean           6.753074     12.175205             8.907459
# std            4.680122      9.021881             5.083477
# ...
