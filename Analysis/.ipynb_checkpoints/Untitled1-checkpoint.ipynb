# %%
cd ..
# Out:
# C:\Users\Ed Center\Documents\GitHub\Week1

# %%
cd Data_And_Data_Creation/
# Out:
# C:\Users\Ed Center\Documents\GitHub\Week1\Data_And_Data_Creation

# %%
cd Time_of_Day
# Out:
# C:\Users\Ed Center\Documents\GitHub\Week1\Data_And_Data_Creation\Time_of_Day

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 72C3-9917
#
#  Directory of C:\Users\Ed Center\Documents\GitHub\Week1\Data_And_Data_Creation\Time_of_Day
#
# 02/29/2020  04:44 PM    <DIR>          .
# 02/29/2020  04:44 PM    <DIR>          ..
# 02/29/2020  04:42 PM            16,655 Welcome Table Sign in 2020 - FEB.csv
# 02/29/2020  04:43 PM            11,037 Welcome Table Sign in 2020 - JAN.csv
#                2 File(s)         27,692 bytes
#                2 Dir(s)  245,373,673,472 bytes free

# %%
feb = pd.read_csv("Welcome Table Sign in 2020 - FEB.csv")

# %%
jan =pd.read_csv("Welcome Table Sign in 2020 - JAN.csv")

# %%
df = pd.concat([jan,feb])

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
df = df.dropna(subset=["Date/Time"])

# %%
df['Day'] = df['Date/Time'].dt.dayofweek
# Out:
# C:\Users\Ed Center\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Hour'] = df['Date/Time'].dt.hour
# Out:
# C:\Users\Ed Center\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#           Date Zip code  # in Group  # New  # Returns  Temperature  \
# 122  1/16/2020    11201         2.0    NaN        2.0           43
# 123  1/16/2020    11201         4.0    NaN        4.0           43
# 124  1/16/2020    11201         2.0    1.0        1.0           43
# 125  1/16/2020    11201         2.0    NaN        2.0           43
# 126  1/16/2020    10030         2.0    2.0        NaN           43
# 127  1/16/2020    11201         3.0    NaN        3.0           43
# 128  1/16/2020    11201         4.0    1.0        3.0           43
# 129  1/16/2020   canada         3.0    3.0        NaN           43
# 130  1/16/2020    11201         2.0    NaN        2.0           43
# 131  1/16/2020    11201         4.0    NaN        4.0           43
# 132  1/16/2020    11201         3.0    NaN        3.0           43
# 133  1/16/2020    11201         2.0    NaN        2.0           43
# 134  1/16/2020    11201         3.0    NaN        3.0           43
# ...

# %%
grouped_df = df.groupby('Day')

# %% [markdown]
# # working on here

# %%
for li in grouped_df:
    print 
    sns.countplot(li["Hour"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-aa2d5b2aef5c> in <module>()
#       1 for li in grouped_df:
# ----> 2     print (li['Hour'])
#       3     sns.countplot(li["Hour"])
#
# TypeError: tuple indices must be integers, not str

# %%
feb_time = feb['Date/Time']

# %%
jan_time = jan['Date/Time']

# %%
feb_time = pd.to_datetime(feb_time)

# %%
jan_time = pd.to_datetime(jan_time)

# %%
feb_time['dayofweek'] = feb_time.dt.dayofweek

# %%
jan_hour = jan_time.dropna().dt.hour

# %%
feb_hour = feb_time.dropna().dt.hour

# %%
total   = list(jan_hour) + list(feb_hour)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
plt.hist(jan_hour)
# Out:
# (array([21.,  0.,  0., 18.,  0.,  0., 55.,  0.,  0., 35.]),
#  array([13. , 13.3, 13.6, 13.9, 14.2, 14.5, 14.8, 15.1, 15.4, 15.7, 16. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(feb_hour)
# Out:
# (array([ 58.,   0.,   0.,  57.,   0.,   0., 107.,   0.,   0.,  88.]),
#  array([13. , 13.3, 13.6, 13.9, 14.2, 14.5, 14.8, 15.1, 15.4, 15.7, 16. ]),
#  <a list of 10 Patch objects>)

# %%
total = [x-12 for x in total]

# %%
sns.countplot(total)
plt.title("January and February count of visiting groups")
plt.xlabel("")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-e31cfdbdeeaf> in <module>()
#       1 sns.countplot(total)
#       2 plt.title("January and February count of visiting groups")
# ----> 3 plt.xlabel()
#       4 plt.show()
#
# TypeError: xlabel() takes at least 1 argument (0 given)

# %%
total
# Out:
# [15L,
#  15L,
#  15L,
#  15L,
#  16L,
#  16L,
#  16L,
#  16L,
#  16L,
#  16L,
#  16L,
#  16L,
#  16L,
#  16L,
#  13L,
#  13L,
#  13L,
#  13L,
#  14L,
#  14L,
#  15L,
#  15L,
#  16L,
#  16L,
#  13L,
#  13L,
#  13L,
#  13L,
#  13L,
#  13L,
#  13L,
#  14L,
#  14L,
#  14L,
#  14L,
#  14L,
#  14L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  16L,
#  16L,
#  16L,
#  16L,
#  15L,
#  15L,
#  15L,
#  15L,
#  16L,
#  16L,
#  16L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  16L,
#  16L,
#  13L,
#  13L,
#  15L,
#  15L,
#  15L,
#  15L,
#  16L,
#  16L,
#  16L,
#  16L,
#  13L,
#  13L,
#  13L,
#  13L,
#  13L,
#  13L,
#  13L,
#  13L,
#  14L,
#  14L,
#  14L,
#  14L,
#  14L,
#  14L,
#  14L,
#  14L,
#  14L,
#  14L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  16L,
#  16L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  16L,
#  16L,
#  16L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  15L,
#  16L,
# ...
