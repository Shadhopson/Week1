# %%
import pandas as pd
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
summed_by_date = pd.read_csv('../Data_And_Data_Creation/expanded_dummied_welcome_table_summed.csv')
import seaborn as sns

# %%
#summed_by_date = summed_by_date[summed_by_date['year'] > 2015]

# %%
weeks_school_is_closed = [40,41,48,52,1,3,4,8,15,16]

# %%
sch_closed = []
for i,x in summed_by_date.iterrows():
    if x['week'] in weeks_school_is_closed:
        sch_closed.append(1)
    else:
        sch_closed.append(0)

# %%
summed_by_date['school_closed'] = sch_closed

# %%
summed_by_date['tempWeekday'] = summed_by_date['Temperature']*(summed_by_date['day_1']+summed_by_date['day_3'])

# %%
summed_by_date['tempWeekend'] = summed_by_date['Temperature']*(summed_by_date['day_5']+summed_by_date['day_6'])

# %%
#summed_by_date['Date'] = pd.to_datetime(summed_by_date['Unnamed: 0.1'])

# %%
holidays = pd.read_csv("../Data_And_Data_Creation/usholidays.csv")

holidays['Date'] = pd.to_datetime(holidays['Date'])

holidays['Month'] = holidays['Date'].dt.month
holidays['week'] = holidays['Date'].dt.week
holidays['year'] = holidays['Date'].dt.year

holiday_week = []
for i, x in summed_by_date.iterrows():
    if holidays[(holidays['year'] == x['year'])& (holidays['week'] == x['week'])].shape[0] > 0:
        holiday_week.append(1)
    else:
        holiday_week.append(0)

# %%
summed_by_date.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'total_visitors', 'total_new',
#        'total_returns', 'from_11201', 'Temperature', 'avg_visits_per_hour',
#        'avg_returns_per_hour', 'avg_new_per_hour', 'avg_from_11201_per_hour',
#        'ratio_11201', 'day', 'week', 'month', 'year', 'given_temp',
#        'precipitation', 'cloud_cover', 'snow', 'rain',
#        'yesterday_visits_per_hour', 'year_2016', 'year_2017', 'year_2018',
#        'year_2019', 'day_1', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6',
#        'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7',
#        'month_8', 'month_9', 'month_10', 'month_11', 'month_12', 'week_2',
#        'week_3', 'week_4', 'week_5', 'week_6', 'week_7', 'week_8', 'week_9',
#        'week_10', 'week_11', 'week_12', 'week_13', 'week_14', 'week_15',
#        'week_16', 'week_17', 'week_18', 'week_19', 'week_20', 'week_21',
#        'week_22', 'week_23', 'week_24', 'week_25', 'week_26', 'week_27',
#        'week_28', 'week_29', 'week_30', 'week_31', 'week_32', 'week_33',
#        'week_34', 'week_35', 'week_36', 'week_37', 'week_38', 'week_39',
#        'week_40', 'week_41', 'week_42', 'week_43', 'week_44', 'week_45',
#        'week_46', 'week_47', 'week_48', 'week_49', 'week_50', 'week_51',
#        'school_closed', 'tempWeekday', 'tempWeekend'],
#       dtype='object')

# %%
#summed_by_date[summed_by_date['Date'].isin(list(holidays['Date']))]

# %%
summed_by_date['holiday_week'] = holiday_week

# %%
summed_by_date = summed_by_date[~(np.abs(summed_by_date.avg_visits_per_hour-summed_by_date.avg_visits_per_hour.mean()) > (3*summed_by_date.avg_visits_per_hour.std()))]

# %%
summed_by_date = summed_by_date[summed_by_date['day'].isin([1,3,5,6])]

# %%
prev_day = []
prev_week = []
for i,x in summed_by_date.iterrows():
    prev_week.append(summed_by_date[(summed_by_date['week'] == x['week']-1) & (summed_by_date['year'] == x['year'])]['avg_visits_per_hour'].mean())
    try:
        prev_day.append(summed_by_date[(summed_by_date['week'] == x['week']-1) & (summed_by_date['year'] == x['year'])&(summed_by_date['day'] == x['day'])]['avg_visits_per_hour'].item())
    except:
        prev_day.append(float('nan'))

# %%
summed_by_date['prev_day'] = prev_day

# %%
summed_by_date['prev_week'] = prev_week

# %%
in_school = []
for i,x in summed_by_date.iterrows():
    if x['month'] > 6 and x['month'] < 9:
        in_school.append(0)
    else:
        in_school.append(1)

# %%
summed_by_date['in_school'] = in_school

# %%
#summed_by_date = summed_by_date.dropna()
Keep = summed_by_date.columns.values[6:]
X = summed_by_date[Keep]
drop = X.columns.values[2:6]
X = X.drop(drop, axis=1)
X = X.drop('given_temp', axis=1)

# %%
X = X.dropna()

# %%
#X = X.drop(['day_2', 'day_4', 'day', 'week', 'year', 'month'], axis=1)
#X =X.dropna()
X = X.reindex()

# %%
#Y = summed_by_date.total_visitors
Y = X.avg_visits_per_hour

# %%
#na_free = X.dropna()
#only_na = X[~X.index.isin(na_free.index)]

# %%
#df['avg_visits_per_hour'] = summed_by_date.total_visitors
#X['avg_visits_per_hour'] = summed_by_date.avg_visits_per_hour

# %%
cor = X.corr()

# %%
#Correlation with output variable
cor_target = abs(cor["avg_visits_per_hour"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.1]
relevant_features
# Out:
# Temperature                  0.314687
# avg_visits_per_hour          1.000000
# day                          0.241483
# year                         0.163515
# precipitation                0.266587
# cloud_cover                  0.263106
# snow                         0.192004
# rain                         0.121923
# yesterday_visits_per_hour    0.215037
# year_2016                    0.141259
# day_1                        0.172795
# day_6                        0.210511
# month_8                      0.208416
# month_12                     0.195657
# week_5                       0.101369
# week_6                       0.136252
# week_31                      0.126130
# week_33                      0.111888
# week_34                      0.136523
# week_43                      0.121591
# week_49                      0.101271
# week_50                      0.128010
# week_51                      0.103166
# tempWeekday                  0.149161
# tempWeekend                  0.309407
# holiday_week                 0.120016
# prev_day                     0.214067
# prev_week                    0.203074
# in_school                    0.221711
# Name: avg_visits_per_hour, dtype: float64

# %%
X= X.drop('avg_visits_per_hour', axis=1)

# %%
#Adding constant column of ones, mandatory for sm.OLS model
X_1 = sm.add_constant(X)
#Fitting sm.OLS model
model = sm.OLS(Y,X_1).fit()
model.pvalues
# Out:
# const                        0.087456
# Temperature                  0.000500
# day                          0.375434
# week                         0.567213
# month                        0.577976
# year                         0.062597
# precipitation                0.000296
# cloud_cover                  0.067143
# snow                         0.054912
# rain                         0.232809
# yesterday_visits_per_hour    0.370527
# year_2016                    0.489083
# year_2017                    0.094610
# year_2018                    0.052846
# year_2019                    0.127725
# day_1                        0.522664
# day_2                        0.000201
# day_3                        0.183462
# day_4                        0.000799
# day_5                        0.007034
# day_6                        0.017363
# month_2                      0.980066
# month_3                      0.625930
# month_4                      0.451777
# month_5                      0.713429
# month_6                      0.697167
# month_7                      0.347982
# month_8                      0.696394
# month_9                      0.270548
# month_10                     0.752096
#                                ...
# week_29                      0.376650
# week_30                      0.095323
# week_31                      0.192430
# week_32                      0.866193
# week_33                      0.178002
# week_34                      0.156259
# week_35                      0.347911
# week_36                      0.243653
# week_37                      0.330953
# week_38                      0.826411
# week_39                      0.264346
# week_40                      0.326291
# week_41                      0.944416
# week_42                      0.549407
# week_43                      0.436480
# week_44                      0.161884
# week_45                      0.450176
# week_46                      0.307206
# week_47                      0.292508
# week_48                      0.240209
# week_49                      0.868869
# week_50                      0.711547
# week_51                      0.329303
# school_closed                0.782569
# tempWeekday                  0.870604
# tempWeekend                  0.000027
# holiday_week                 0.019350
# prev_day                     0.265030
# prev_week                    0.889500
# in_school                    0.372243
# Length: 89, dtype: float64

# %%
#Backward Elimination
cols = list(X.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = X[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(Y,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['Temperature', 'day', 'week', 'year', 'precipitation', 'cloud_cover', 'snow', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'month_3', 'month_4', 'week_7', 'week_8', 'week_31', 'week_33', 'week_34', 'tempWeekend', 'holiday_week']

# %%
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, 7)
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,Y)  
#Fitting the data to model
model.fit(X_rfe,Y)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False False False  True False False False False False  True  True
#   True  True False False False False  True  True False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False]
# [23  3 73 42  1 75 76 77 79 81  1  1  1  1  2 45 13 44  1  1 35 38 40 36
#  41 19 20 37 43 33 17 39  6  5 53 56 27 12 54 48 51 50 67 55 11  8 70 69
#  47 66 46 58 71 57 49 68 29 64 62 28 60 21 61 59 65 26 63 52 72 10  9 74
#  25 30 34 31 32  4 16 15 14  7 24 22 78 80 82 18]

# %%
reg = LassoCV()
reg.fit(X, Y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,Y))
coef = pd.Series(reg.coef_, index = X.columns)
# Out:
# Best alpha using built-in LassoCV: 0.077734
# Best score using built-in LassoCV: 0.300822

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 21 variables and eliminated the other 67 variables

# %%
cols2 = list(coef[coef !=0].index)
#X = X[cols2]
#X = X[selected_features_BE]
#X= X[list(relevant_features.index)]

# %%
X.shape[0]
# Out:
# 625

# %%
train_max = round(3.0/4*X.shape[0])

# %%
X_train = X.iloc[:train_max,:]
X_test = X.iloc[train_max:,:]
y_train = Y.iloc[:train_max]
y_test = Y.iloc[train_max:]

# %%
nof_list=np.arange(1,77)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    
    #X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 13
# Score with 13 features: 0.119070

# %%
list(relevant_features.index)
# Out:
# ['Temperature',
#  'avg_visits_per_hour',
#  'day',
#  'year',
#  'precipitation',
#  'cloud_cover',
#  'snow',
#  'rain',
#  'yesterday_visits_per_hour',
#  'year_2016',
#  'day_1',
#  'day_6',
#  'month_8',
#  'month_12',
#  'week_5',
#  'week_6',
#  'week_31',
#  'week_33',
#  'week_34',
#  'week_43',
#  'week_49',
#  'week_50',
#  'week_51',
#  'tempWeekday',
#  'tempWeekend',
#  'holiday_week',
#  'prev_day',
#  'prev_week',
#  'in_school']

# %%
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5,1,'Feature importance using Lasso Model')

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, Y)

print(f'Coefficients: {lin_reg.coef_}')
print(f'Intercept: {lin_reg.intercept_}')
print(f'R^2 score: {lin_reg.score(X, Y)}')
# Out:
# Coefficients: [-8.82515353e+07  1.69230451e+09 -1.10533977e+06  8.70968424e+07
#  -4.12941409e+10 -1.27203480e+02 -2.58513224e+00 -3.57412061e+00
#  -8.76404403e-01  3.06892395e-02  4.12941409e+10  8.25882818e+10
#   1.23882423e+11  1.65176564e+11  5.24657322e+09  4.79003215e+08
#   1.86196420e+09 -1.02373803e+09 -1.52264482e+09 -3.21494933e+09
# week_34                       5.9157      4.167      1.420      0.156      -2.269      14.101
# week_35                       3.3288      3.543      0.939      0.348      -3.631      10.289
# week_36                       4.6291      3.966      1.167      0.244      -3.162      12.420
# week_37                       3.6438      3.745      0.973      0.331      -3.712      11.000
# week_38                       0.7623      3.474      0.219      0.826      -6.062       7.587
# week_39                       3.3752      3.021      1.117      0.264      -2.559       9.309
# week_40                       2.6334      2.680      0.982      0.326      -2.632       7.898
# week_41                      -0.1755      2.517     -0.070      0.944      -5.119       4.768
# week_42                       2.0477      3.418      0.599      0.549      -4.667       8.763
# week_43                      -2.6849      3.448     -0.779      0.436      -9.457       4.088
# week_44                      -5.2193      3.726     -1.401      0.162     -12.539       2.100
# week_45                      -3.2842      4.346     -0.756      0.450     -11.821       5.253
# week_46                      -4.3994      4.304     -1.022      0.307     -12.855       4.056
# week_47                      -5.0939      4.835     -1.054      0.293     -14.591       4.403
# week_48                      -4.6443      3.950     -1.176      0.240     -12.403       3.115
# week_49                       0.2565      1.553      0.165      0.869      -2.794       3.307
# week_50                      -0.5596      1.513     -0.370      0.712      -3.531       2.412
# week_51                      -1.8650      1.910     -0.976      0.329      -5.617       1.887
# school_closed                -0.6065      2.196     -0.276      0.783      -4.921       3.708
# tempWeekday                  -0.0032      0.019     -0.163      0.871      -0.041       0.035
# tempWeekend                   0.0822      0.019      4.231      0.000       0.044       0.120
# holiday_week                  3.0149      1.285      2.346      0.019       0.490       5.540
# prev_day                      0.0519      0.047      1.116      0.265      -0.039       0.143
# prev_week                    -0.0127      0.092     -0.139      0.889      -0.193       0.167
# in_school                     2.2025      2.466      0.893      0.372      -2.642       7.047
# ==============================================================================
# Omnibus:                       14.360   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.718
# Skew:                           0.368   Prob(JB):                     0.000637
# Kurtosis:                       3.150   Cond. No.                     2.37e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.53e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import seaborn as sns 
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

def linearity_test(model, y):
    '''
    Function for visually inspecting the assumption of linearity in a linear regression model.
    It plots observed vs. predicted values and residuals vs. predicted values.
    
    Args:
    * model - fitted OLS model from statsmodels
    * y - observed values
    '''
    fitted_vals = model.predict()
    resids = model.resid

    fig, ax = plt.subplots(1,2)
    
    sns.regplot(x=fitted_vals, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
    ax[0].set(xlabel='Predicted', ylabel='Observed')

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
    ax[1].set(xlabel='Predicted', ylabel='Residuals')
    
linearity_test(lin_reg, Y)

# %%
lin_reg.resid.mean()
# Out:
# 4.4976712842981214e-11

# %%
X_constant = sm.add_constant(X)
lin_reg = sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     avg_visits_per_hour   R-squared:                       0.398
# Model:                             OLS   Adj. R-squared:                  0.315
# Method:                  Least Squares   F-statistic:                     4.770
# Date:                 Wed, 10 Jul 2019   Prob (F-statistic):           1.02e-27
# Time:                         13:21:20   Log-Likelihood:                -1993.5
# No. Observations:                  625   AIC:                             4141.
# Df Residuals:                      548   BIC:                             4483.
# Df Model:                           76
# Covariance Type:             nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.
+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.53e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
import statsmodels.tsa.api as smt

acf = smt.graphics.plot_acf(lin_reg.resid, lags=40 , alpha=0.05)
acf.show()
# Out:
# /Users/ngagnon/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
from sklearn.ensemble import GradientBoostingRegressor

est = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=0, loss='ls').fit(X_train, y_train)

print("Mean squared error: %.2f"
      % mean_squared_error(y_test, est.predict(X_test)))
print('Variance score: %.2f' % r2_score(y_test, est.predict(X_test)))

plt.figure(figsize=(5,5))
plt.scatter(y_test, est.predict(X_test), color='blue', linewidth=3)
plt.xlabel('Real Values')
plt.ylabel('Predicted Values')
plt.plot([0,200], [0,200])
plt.xticks(range(0,50,5))
plt.ylim(0,50)
plt.xlim(0,50)
plt.show()
# Out:
# Mean squared error: 37.87
# Variance score: 0.20

# %%
est.predict(X_test)
# Out:
# array([16.50292817, 19.20269653, 10.06841455, 13.61818709, 24.19633637,
#        28.07413327, 10.57464939, 18.36031182, 17.11864992, 16.50379936,
#        14.91287732, 21.76169429, 22.7555055 , 25.53972123, 18.17710978,
#        20.0086637 , 18.00599496, 17.16189924, 11.56476303,  8.17828049,
#        18.65914521, 23.15392129, 21.19295815, 15.40676326, 20.36479954,
#        19.55341942, 25.02401133, 24.31654395, 25.22827709, 25.29389562,
#        15.38927373, 17.42524333, 20.5702598 , 20.21877387, 12.86895548,
#        10.22951577, 21.60201999, 15.07356717, 15.66894997, 12.82188326,
#        22.77441118, 21.26743103, 15.67032084, 16.64268686, 19.27570487,
#        18.15069812,  9.15230099, 12.41572039, 21.39146493, 18.84992036,
#         7.94387947, 19.17988112, 23.38139453, 19.37065668, 14.27894707,
#        15.10586906, 16.01171135, 19.10655293, 16.98849738, 17.54142501,
#        14.82625659, 13.68195974,  6.39848098, 13.92883865, 10.17252705,
#        13.96507046, 10.34009695, 18.74145648, 11.32934238, 11.30198356,
#        20.96912585, 11.07755509,  9.87386389, 14.60089574, 18.01760644,
#        15.27091799, 13.67019029, 13.22032437, 12.82650673, 14.48520641,
#        15.13216767, 12.17722943, 12.5464966 , 10.53837936,  7.06568429,
#        12.29706336, 13.88782639, 12.78111103, 10.72400139, 15.01808856,
#        14.61627213, 11.54387611,  8.49665129, 14.17483981, 10.33940422,
#        16.04066976, 19.92371471,  9.63796574,  9.03122386, 17.79392667,
#        19.40885256, 16.74867897, 12.77227701, 15.10104476, 10.11639925,
#        20.09733015, 21.08929958, 16.86550807, 20.61742052, 13.2028924 ,
#        19.44790674, 15.47585275, 14.74651748, 14.0667889 , 15.54358872,
#        16.16522133, 19.4951535 , 18.80517509, 16.78667436, 16.11448963,
#        23.1638477 , 16.99287823, 15.83583124, 18.15646198, 16.67951336,
#        16.65627664, 16.20509833, 25.2568042 , 16.82025271, 18.66570257,
#        16.91287633, 15.08608462, 11.47790955, 22.00577272, 16.5822933 ,
#        19.21659921, 17.09225671, 20.17042419, 12.18829265, 14.09314691,
#        15.32190885,  8.91159834, 11.15222426, 13.94342603, 14.47432232,
#        11.04959317,  8.80976466, 13.97695679, 18.53663983, 18.82529103,
#        13.33579129,  6.64987126, 20.17898967, 19.19783203, 12.55248038,
#        10.78373759])

# %%
X_test['pred'] = est.predict(X_test)
# Out:
# /Users/ngagnon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test['real'] = y_test
# Out:
# /Users/ngagnon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test['Diff'] =  abs(X_test['pred'] - X_test['real'])
# Out:
# /Users/ngagnon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test["Diff"].mean()
# Out:
# 4.941261663624144

# %%
X_test['Diff'].std()
# Out:
# 3.6796861051511707

# %%
X_test[X_test['Diff']>20]
# Out:
# Empty DataFrame
# Columns: [Temperature, day, week, month, year, precipitation, cloud_cover, snow, rain, yesterday_visits_per_hour, year_2016, year_2017, year_2018, year_2019, day_1, day_2, day_3, day_4, day_5, day_6, month_2, month_3, month_4, month_5, month_6, month_7, month_8, month_9, month_10, month_11, month_12, week_2, week_3, week_4, week_5, week_6, week_7, week_8, week_9, week_10, week_11, week_12, week_13, week_14, week_15, week_16, week_17, week_18, week_19, week_20, week_21, week_22, week_23, week_24, week_25, week_26, week_27, week_28, week_29, week_30, week_31, week_32, week_33, week_34, week_35, week_36, week_37, week_38, week_39, week_40, week_41, week_42, week_43, week_44, week_45, week_46, week_47, week_48, week_49, week_50, week_51, school_closed, tempWeekday, tempWeekend, holiday_week, prev_day, prev_week, in_school, pred, real, Diff]
# Index: []
#
# [0 rows x 91 columns]

# %%
hols = summed_by_date[summed_by_date['holiday_week']==1]

# %%
not_hols = summed_by_date[summed_by_date['holiday_week']==0]

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(hols['avg_visits_per_hour'], not_hols['avg_visits_per_hour'])
# Out:
# Ttest_indResult(statistic=1.7470188112496081, pvalue=0.08107325191754257)

# %%
not_hols.describe()
# Out:
#        Unnamed: 0  total_visitors   total_new  total_returns  from_11201  \
# count  591.000000      591.000000  591.000000     591.000000  542.000000
# mean   359.940778       52.043993   29.494078      22.412860   22.634686
# std    205.487477       31.834340   26.356028      12.396641   11.291767
# min      0.000000        2.000000    0.000000       0.000000    0.000000
# 25%    179.500000       27.000000    7.000000      14.000000   15.000000
# 50%    359.000000       44.000000   22.000000      21.000000   21.000000
# 75%    536.500000       76.000000   47.000000      30.000000   29.000000
# max    710.000000      167.000000  114.000000      69.000000   68.000000
#
#        Temperature  avg_visits_per_hour  avg_returns_per_hour  \
# count   591.000000           591.000000            591.000000
# mean     61.965871            16.631557              7.843486
# std      16.804113             7.355107              4.235048
# min      16.180000             1.000000              0.000000
# 25%      47.985000            11.000000              4.625000
# 50%      62.480000            16.500000              7.500000
# 75%      76.585000            21.500000             10.250000
# max      94.700000            41.750000             23.000000
#
#        avg_new_per_hour  avg_from_11201_per_hour     ...         week_49  \
# count        591.000000               542.000000     ...      591.000000
# mean           8.747039                 8.119465     ...        0.025381
# std            6.599025                 4.200267     ...        0.157412
# min            0.000000                 0.000000     ...        0.000000
# 25%            3.375000                 5.000000     ...        0.000000
# 50%            7.250000                 7.500000     ...        0.000000
# 75%           13.125000                10.500000     ...        0.000000
# max           28.500000                21.500000     ...        1.000000
#
#           week_50     week_51  school_closed  tempWeekday  tempWeekend  \
# count  591.000000  591.000000     591.000000   591.000000   591.000000
# mean     0.025381    0.015228       0.137056    30.261557    31.704315
# std      0.157412    0.122564       0.344198    33.172625    33.227267
# min      0.000000    0.000000       0.000000     0.000000     0.000000
# 25%      0.000000    0.000000       0.000000     0.000000     0.000000
# 50%      0.000000    0.000000       0.000000     0.000000    32.120000
# 75%      0.000000    0.000000       0.000000    60.300000    63.165000
# max      1.000000    1.000000       1.000000    93.700000    94.700000
#
#        holiday_week    prev_day   prev_week   in_school
# count         591.0  552.000000  585.000000  591.000000
# mean            0.0   17.079710   17.007621    0.835871
# std             0.0    7.506001    4.835426    0.370706
# min             0.0    1.000000    4.875000    0.000000
# 25%             0.0   11.500000   13.916667    1.000000
# 50%             0.0   17.000000   17.000000    1.000000
# 75%             0.0   21.750000   20.000000    1.000000
# max             0.0   42.500000   29.937500    1.000000
#
# [8 rows x 98 columns]

# %%
hols.describe()
# Out:
#        Unnamed: 0  total_visitors   total_new  total_returns  from_11201  \
# count  110.000000      110.000000  110.000000     110.000000   99.000000
# mean   355.109091       55.618182   32.309091      23.145455   25.323232
# std    203.846693       34.651339   29.928583      13.045324   13.933390
# min      7.000000        5.000000    0.000000       0.000000    3.000000
# 25%    205.250000       28.250000    7.000000      15.000000   15.000000
# 50%    359.500000       49.500000   23.500000      20.500000   23.000000
# 75%    536.750000       77.000000   49.000000      31.750000   31.500000
# max    712.000000      148.000000  122.000000      63.000000   74.000000
#
#        Temperature  avg_visits_per_hour  avg_returns_per_hour  \
# count   110.000000           110.000000            110.000000
# mean     59.261091            18.009091              8.263636
# std      18.060618             8.771561              4.991832
# min      13.950000             2.500000              0.000000
# 25%      46.132500            11.125000              4.500000
# 50%      59.320000            16.875000              7.500000
# 75%      74.485000            23.437500             11.125000
# max      91.690000            42.500000             25.000000
#
#        avg_new_per_hour  avg_from_11201_per_hour     ...      week_49  \
# count        110.000000                99.000000     ...        110.0
# mean           9.709091                 9.106061     ...          0.0
# std            7.624767                 5.473509     ...          0.0
# min            0.000000                 1.500000     ...          0.0
# 25%            3.500000                 5.875000     ...          0.0
# 50%            8.000000                 7.500000     ...          0.0
# 75%           13.687500                11.875000     ...          0.0
# max           31.000000                37.000000     ...          0.0
#
#        week_50  week_51  school_closed  tempWeekday  tempWeekend  \
# count    110.0    110.0     110.000000   110.000000   110.000000
# mean       0.0      0.0       0.427273    29.924545    29.336545
# std        0.0      0.0       0.496946    33.320278    31.429581
# min        0.0      0.0       0.000000     0.000000     0.000000
# 25%        0.0      0.0       0.000000     0.000000     0.000000
# 50%        0.0      0.0       0.000000     0.000000    16.100000
# 75%        0.0      0.0       1.000000    59.727500    58.060000
# max        0.0      0.0       1.000000    91.690000    86.530000
#
#        holiday_week   prev_day  prev_week   in_school
# count         110.0  92.000000  94.000000  110.000000
# mean            1.0  16.149457  16.360372    0.900000
# std             0.0   7.881075   5.247579    0.301373
# min             1.0   1.000000   6.875000    0.000000
# 25%             1.0  10.375000  12.187500    1.000000
# 50%             1.0  15.000000  16.343750    1.000000
# 75%             1.0  20.812500  18.500000    1.000000
# max             1.0  41.750000  26.437500    1.000000
#
# [8 rows x 98 columns]

# %%
>15 = low
25>x>15 = medium
x>20 = high
# Out:
#   File "<ipython-input-561-9466c92e5d35>", line 1
#     >15 = low
#     ^
# SyntaxError: invalid syntax
