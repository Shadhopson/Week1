# %%
import pandas as pd
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
summed_by_date = pd.read_csv('../Data_And_Data_Creation/expanded_dummied_welcome_table_summed.csv')
import seaborn as sns

# %%
weeks_school_is_closed = [40,41,48,52,1,3,4,8,15,16]

# %%
sch_closed = []
for i,x in summed_by_date.iterrows():
    if x['week'] in weeks_school_is_closed:
        sch_closed.append(1)
    else:
        sch_closed.append(0)

# %%
summed_by_date['school_closed'] = sch_closed

# %%
summed_by_date['tempWeekday'] = summed_by_date['Temperature']*(summed_by_date['day_1']+summed_by_date['day_3'])

# %%
summed_by_date['tempWeekend'] = summed_by_date['Temperature']*(summed_by_date['day_5']+summed_by_date['day_6'])

# %%
holidays = pd.read_csv("../Data_And_Data_Creation/usholidays.csv")

holidays['Date'] = pd.to_datetime(holidays['Date'])

holidays['Month'] = holidays['Date'].dt.month
holidays['week'] = holidays['Date'].dt.week
holidays['year'] = holidays['Date'].dt.year

holiday_week = []
for i, x in summed_by_date.iterrows():
    if holidays[(holidays['year'] == x['year'])& (holidays['week'] == x['week'])].shape[0] > 0:
        holiday_week.append(1)
    else:
        holiday_week.append(0)

# %%
summed_by_date['holiday_week'] = holiday_week

# %%
summed_by_date = summed_by_date[~(np.abs(summed_by_date.avg_visits_per_hour-summed_by_date.avg_visits_per_hour.mean()) > (3*summed_by_date.avg_visits_per_hour.std()))]

# %%
summed_by_date = summed_by_date[summed_by_date['day'].isin([1,3,5,6])]

# %%
prev_day = []
prev_week = []
for i,x in summed_by_date.iterrows():
    prev_week.append(summed_by_date[(summed_by_date['week'] == x['week']-1) & (summed_by_date['year'] == x['year'])]['avg_visits_per_hour'].mean())
    try:
        prev_day.append(summed_by_date[(summed_by_date['week'] == x['week']-1) & (summed_by_date['year'] == x['year'])&(summed_by_date['day'] == x['day'])]['avg_visits_per_hour'].item())
    except:
        prev_day.append(float('nan'))

# %%
summed_by_date['prev_day'] = prev_day

# %%
summed_by_date['prev_week'] = prev_week

# %%
in_school = []
for i,x in summed_by_date.iterrows():
    if x['month'] > 6 and x['month'] < 9:
        in_school.append(0)
    else:
        in_school.append(1)

# %%
summed_by_date['in_school'] = in_school

# %%
#summed_by_date = summed_by_date.dropna()
Keep = summed_by_date.columns.values[6:]
X = summed_by_date[Keep]
drop = X.columns.values[2:6]
X = X.drop(drop, axis=1)
X = X.drop('given_temp', axis=1)

# %%
X = X.dropna()

# %%
#X = X.drop(['day_2', 'day_4', 'day', 'week', 'year', 'month'], axis=1)
#X =X.dropna()
X = X.reindex()

# %%
#Y = summed_by_date.total_visitors
Y = X.avg_visits_per_hour

# %%
#na_free = X.dropna()
#only_na = X[~X.index.isin(na_free.index)]

# %%
#df['avg_visits_per_hour'] = summed_by_date.total_visitors
#X['avg_visits_per_hour'] = summed_by_date.avg_visits_per_hour

# %%
cor = X.corr()

# %%
#Correlation with output variable
cor_target = abs(cor["avg_visits_per_hour"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.1]
relevant_features
# Out:
# Temperature                  0.314687
# avg_visits_per_hour          1.000000
# day                          0.241483
# year                         0.163515
# precipitation                0.266587
# cloud_cover                  0.263106
# snow                         0.192004
# rain                         0.121923
# yesterday_visits_per_hour    0.215037
# year_2016                    0.141259
# day_1                        0.172795
# day_6                        0.210511
# month_8                      0.208416
# month_12                     0.195657
# week_5                       0.101369
# week_6                       0.136252
# week_31                      0.126130
# week_33                      0.111888
# week_34                      0.136523
# week_43                      0.121591
# week_49                      0.101271
# week_50                      0.128010
# week_51                      0.103166
# tempWeekday                  0.149161
# tempWeekend                  0.309407
# holiday_week                 0.120016
# prev_day                     0.214067
# prev_week                    0.203074
# in_school                    0.221711
# Name: avg_visits_per_hour, dtype: float64

# %%
X= X.drop('avg_visits_per_hour', axis=1)

# %%
#Adding constant column of ones, mandatory for sm.OLS model
X_1 = sm.add_constant(X)
#Fitting sm.OLS model
model = sm.OLS(Y,X_1).fit()
model.pvalues
# Out:
# const                        0.087456
# Temperature                  0.000500
# day                          0.375434
# week                         0.567213
# month                        0.577976
# year                         0.062597
# precipitation                0.000296
# cloud_cover                  0.067143
# snow                         0.054912
# rain                         0.232809
# yesterday_visits_per_hour    0.370527
# year_2016                    0.489083
# year_2017                    0.094610
# year_2018                    0.052846
# year_2019                    0.127725
# day_1                        0.522664
# day_2                        0.000201
# day_3                        0.183462
# day_4                        0.000799
# day_5                        0.007034
# day_6                        0.017363
# month_2                      0.980066
# month_3                      0.625930
# month_4                      0.451777
# month_5                      0.713429
# month_6                      0.697167
# month_7                      0.347982
# month_8                      0.696394
# month_9                      0.270548
# month_10                     0.752096
#                                ...
# week_29                      0.376650
# week_30                      0.095323
# week_31                      0.192430
# week_32                      0.866193
# week_33                      0.178002
# week_34                      0.156259
# week_35                      0.347911
# week_36                      0.243653
# week_37                      0.330953
# week_38                      0.826411
# week_39                      0.264346
# week_40                      0.326291
# week_41                      0.944416
# week_42                      0.549407
# week_43                      0.436480
# week_44                      0.161884
# week_45                      0.450176
# week_46                      0.307206
# week_47                      0.292508
# week_48                      0.240209
# week_49                      0.868869
# week_50                      0.711547
# week_51                      0.329303
# school_closed                0.782569
# tempWeekday                  0.870604
# tempWeekend                  0.000027
# holiday_week                 0.019350
# prev_day                     0.265030
# prev_week                    0.889500
# in_school                    0.372243
# Length: 89, dtype: float64

# %%
#Backward Elimination
cols = list(X.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = X[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(Y,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['Temperature', 'day', 'week', 'year', 'precipitation', 'cloud_cover', 'snow', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'month_3', 'month_4', 'week_7', 'week_8', 'week_31', 'week_33', 'week_34', 'tempWeekend', 'holiday_week']

# %%
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, 7)
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,Y)  
#Fitting the data to model
model.fit(X_rfe,Y)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False False False  True False False False False False  True  True
#   True  True False False False False  True  True False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False]
# [23  3 73 42  1 75 76 77 79 81  1  1  1  1  2 45 13 44  1  1 35 38 40 36
#  41 19 20 37 43 33 17 39  6  5 53 56 27 12 54 48 51 50 67 55 11  8 70 69
#  47 66 46 58 71 57 49 68 29 64 62 28 60 21 61 59 65 26 63 52 72 10  9 74
#  25 30 34 31 32  4 16 15 14  7 24 22 78 80 82 18]

# %%
reg = LassoCV()
reg.fit(X, Y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,Y))
coef = pd.Series(reg.coef_, index = X.columns)
# Out:
# Best alpha using built-in LassoCV: 0.077734
# Best score using built-in LassoCV: 0.300822

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 21 variables and eliminated the other 67 variables

# %%
cols2 = list(coef[coef !=0].index)
X = X[cols2]
#X = X[selected_features_BE]
#X= X[list(relevant_features.index)]

# %%
nof_list=np.arange(1,77)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 5
# Score with 5 features: 0.165877

# %%
list(relevant_features.index)
# Out:
# ['Temperature',
#  'avg_visits_per_hour',
#  'day',
#  'year',
#  'precipitation',
#  'cloud_cover',
#  'snow',
#  'rain',
#  'yesterday_visits_per_hour',
#  'year_2016',
#  'day_1',
#  'day_6',
#  'month_8',
#  'month_12',
#  'week_5',
#  'week_6',
#  'week_31',
#  'week_33',
#  'week_34',
#  'week_43',
#  'week_49',
#  'week_50',
#  'week_51',
#  'tempWeekday',
#  'tempWeekend',
#  'holiday_week',
#  'prev_day',
#  'prev_week',
#  'in_school']

# %%
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5,1,'Feature importance using Lasso Model')

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, Y)

print(f'Coefficients: {lin_reg.coef_}')
print(f'Intercept: {lin_reg.intercept_}')
print(f'R^2 score: {lin_reg.score(X, Y)}')
# Out:
# Coefficients: [ 0.08433571 -0.03214444 -0.07422526 -0.45507966 -3.66573771 -4.49982856
#  -1.39765422  0.07661199  0.571455   -0.25849107  1.09055366 -1.91786242
#   1.13332935 -1.48674438  3.04476785 -3.14376661 -3.8286478   0.07754809
#   3.2083371   0.06212494 -0.04044197]
# Intercept: 929.3102914054048
# R^2 score: 0.32216467902840684

# %%
X_constant = sm.add_constant(X)
lin_reg = sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     avg_visits_per_hour   R-squared:                       0.322
# Model:                             OLS   Adj. R-squared:                  0.299
# Method:                  Least Squares   F-statistic:                     13.65
# Date:                 Sat, 06 Jul 2019   Prob (F-statistic):           1.02e-38
# Time:                         12:29:30   Log-Likelihood:                -2030.7
# No. Observations:                  625   AIC:                             4105.
# Df Residuals:                      603   BIC:                             4203.
# Df Model:                           21
# Covariance Type:             nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                       929.3103    750.220      1.239      0.216    -544.051    2402.672
# Temperature                   0.0843      0.026      3.281      0.001       0.034       0.135
# day                          -0.0321      0.405     -0.079      0.937      -0.828       0.763
# week                         -0.0742      0.023     -3.267      0.001      -0.119      -0.030
# year                         -0.4551      0.372     -1.225      0.221      -1.185       0.275
# cloud_cover                  -3.6657      1.290     -2.841      0.005      -6.200      -1.131
# snow                         -4.4998      1.750     -2.571      0.010      -7.937      -1.063
# rain                         -1.3977      0.684     -2.042      0.042      -2.742      -0.054
# yesterday_visits_per_hour     0.0766      0.033      2.321      0.021       0.012       0.141
# year_2016                     0.5715      0.900      0.635      0.526      -1.197       2.340
# year_2017                    -0.2585      0.690     -0.374      0.708      -1.614       1.097
# day_3                         1.0906      1.012      1.077      0.282      -0.897       3.078
# day_5                        -1.9179      0.766     -2.504      0.013      -3.422      -0.414
# month_3                       1.1333      0.978      1.159      0.247      -0.787       3.054
# month_5                      -1.4867      0.885     -1.680      0.094      -3.225       0.252
# month_8                       3.0448      1.025      2.971      0.003       1.032       5.058
# week_6                       -3.1438      1.864     -1.687      0.092      -6.804       0.516
# week_43                      -3.8286      1.834     -2.087      0.037      -7.431      -0.226
# tempWeekend                   0.0775      0.030      2.546      0.011       0.018       0.137
# holiday_week                  3.2083      0.747      4.292      0.000       1.740       4.676
# prev_day                      0.0621      0.046      1.341      0.180      -0.029       0.153
# prev_week                    -0.0404      0.077     -0.527      0.599      -0.191       0.110
# ==============================================================================
# Omnibus:                       23.313   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.525
# Skew:                           0.441   Prob(JB):                     2.87e-06
# Kurtosis:                       3.451   Cond. No.                     5.96e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.96e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import seaborn as sns 
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

def linearity_test(model, y):
    '''
    Function for visually inspecting the assumption of linearity in a linear regression model.
    It plots observed vs. predicted values and residuals vs. predicted values.
    
    Args:
    * model - fitted OLS model from statsmodels
    * y - observed values
    '''
    fitted_vals = model.predict()
    resids = model.resid

    fig, ax = plt.subplots(1,2)
    
    sns.regplot(x=fitted_vals, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
    ax[0].set(xlabel='Predicted', ylabel='Observed')

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
    ax[1].set(xlabel='Predicted', ylabel='Residuals')
    
linearity_test(lin_reg, Y)

# %%
lin_reg.resid.mean()
# Out:
# -3.4169119089710877e-12

# %%
X_constant = sm.add_constant(X)
lin_reg = sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     avg_visits_per_hour   R-squared:                       0.322
# Model:                             OLS   Adj. R-squared:                  0.299
# Method:                  Least Squares   F-statistic:                     13.65
# Date:                 Sat, 06 Jul 2019   Prob (F-statistic):           1.02e-38
# Time:                         12:29:31   Log-Likelihood:                -2030.7
# No. Observations:                  625   AIC:                             4105.
# Df Residuals:                      603   BIC:                             4203.
# Df Model:                           21
# Covariance Type:             nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                       929.3103    750.220      1.239      0.216    -544.051    2402.672
# Temperature                   0.0843      0.026      3.281      0.001       0.034       0.135
# day                          -0.0321      0.405     -0.079      0.937      -0.828       0.763
# week                         -0.0742      0.023     -3.267      0.001      -0.119      -0.030
# year                         -0.4551      0.372     -1.225      0.221      -1.185       0.275
# cloud_cover                  -3.6657      1.290     -2.841      0.005      -6.200      -1.131
# snow                         -4.4998      1.750     -2.571      0.010      -7.937      -1.063
# rain                         -1.3977      0.684     -2.042      0.042      -2.742      -0.054
# yesterday_visits_per_hour     0.0766      0.033      2.321      0.021       0.012       0.141
# year_2016                     0.5715      0.900      0.635      0.526      -1.197       2.340
# year_2017                    -0.2585      0.690     -0.374      0.708      -1.614       1.097
# day_3                         1.0906      1.012      1.077      0.282      -0.897       3.078
# day_5                        -1.9179      0.766     -2.504      0.013      -3.422      -0.414
# month_3                       1.1333      0.978      1.159      0.247      -0.787       3.054
# month_5                      -1.4867      0.885     -1.680      0.094      -3.225       0.252
# month_8                       3.0448      1.025      2.971      0.003       1.032       5.058
# week_6                       -3.1438      1.864     -1.687      0.092      -6.804       0.516
# week_43                      -3.8286      1.834     -2.087      0.037      -7.431      -0.226
# tempWeekend                   0.0775      0.030      2.546      0.011       0.018       0.137
# holiday_week                  3.2083      0.747      4.292      0.000       1.740       4.676
# prev_day                      0.0621      0.046      1.341      0.180      -0.029       0.153
# prev_week                    -0.0404      0.077     -0.527      0.599      -0.191       0.110
# ==============================================================================
# Omnibus:                       23.313   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.525
# Skew:                           0.441   Prob(JB):                     2.87e-06
# Kurtosis:                       3.451   Cond. No.                     5.96e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.96e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.tsa.api as smt

acf = smt.graphics.plot_acf(lin_reg.resid, lags=40 , alpha=0.05)
acf.show()
# Out:
# /Users/ngagnon/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
from sklearn.ensemble import GradientBoostingRegressor

est = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=0, loss='ls').fit(X_train, y_train)

print("Mean squared error: %.2f"
      % mean_squared_error(y_test, est.predict(X_test)))
print('Variance score: %.2f' % r2_score(y_test, est.predict(X_test)))

plt.figure(figsize=(5,5))
plt.scatter(y_test, est.predict(X_test), color='blue', linewidth=3)
plt.xlabel('Real Values')
plt.ylabel('Predicted Values')
plt.plot([0,200], [0,200])
plt.xticks(range(0,50,5))
plt.ylim(0,50)
plt.xlim(0,50)
plt.show()
# Out:
# Mean squared error: 41.74
# Variance score: 0.18

# %%
est.predict(X_test)
# Out:
# array([ 8.46297622, 21.29846981, 19.1713429 , 21.00574693, 11.73973272,
#        34.58137171, 26.34888629, 14.78412656,  9.2591163 , 20.26689598,
#        11.0425749 , 32.55300154, 13.5553513 , 16.87041114, 20.93041574,
#        16.51506282, 14.49866868, 14.94208056, 16.23560185, 20.46362402,
#        11.07167975, 16.8111063 , 14.93784738, 12.13502568,  9.07278865,
#        17.34262521,  8.02784259, 16.31836385, 11.3220871 , 15.47302208,
#        11.83709817, 15.05586966, 18.21037973, 11.63369834, 16.47809029,
#         7.71037528, 17.40835866, 17.3856383 , 18.02165148, 24.27256375,
#        22.42189896,  4.74613108,  8.20586209, 20.49918096, 15.63884479,
#        15.57124794, 11.98604184, 22.33903577, 17.56957419, 22.21973847,
#        22.53630883, 24.48908206, 14.95906648, 13.36118871, 18.02187278,
#        19.98277543, 20.86858732, 14.05591866, 19.32613627, 11.12379841,
#        22.23943241, 15.54351592, 16.30867423, 13.30368295, 15.7592494 ,
#        10.35888581, 15.87154705, 20.42144917, 20.06553111, 13.88970897,
#        17.39393139, 19.3360536 , 18.43957419, 27.25850038, 16.32698262,
#        17.20978934, 17.47520157, 20.86849256, 16.66044974, 13.41695718,
#        23.54574075, 24.6006747 , 21.22924978, 12.43039069, 16.96188364,
#         9.56062383, 10.94690852, 15.56913316, 14.02647183, 16.00519925,
#        15.43440203, 21.47400476, 17.04121358, 24.28024543, 15.98937044,
#        17.80493695, 14.78532298, 28.20031445, 21.28472798, 16.01651862,
#        13.08601072, 11.24023877, 14.00350122, 17.84805335, 10.31933708,
#        17.88974293, 11.12604112, 27.91054769, 13.29414201, 13.62611608,
#        14.55703581, 14.69003494, 14.78937692, 25.5948574 , 14.39421365,
#        16.13341476, 28.09525685, 14.42590914, 20.13110951, 21.93798523,
#        11.00551381, 17.45750303, 12.85386345, 20.92427644, 15.29038159,
#        17.40030055, 21.51953752, 14.74800835, 18.39503553, 23.28350607,
#        15.63708676, 14.73356467, 18.1590951 , 12.77721411, 12.68017792,
#        19.3510667 , 24.28703709, 12.46389235, 21.58620615, 14.39288909,
#        11.78608583, 16.62390539, 15.22061631, 15.67344561, 12.06374515,
#        16.11217148, 16.99039249, 22.5308058 , 14.22403467, 15.12015797,
#        15.61969018, 14.92539356, 13.74795671, 12.62332876, 22.53336896,
#        10.29286322, 14.03144835, 13.95562326, 17.6472917 , 17.6165775 ,
#        19.90974387, 10.43658382, 16.33637474, 18.19459713, 14.9854005 ,
#        23.61516367, 23.83558935, 14.5334837 , 15.07744095, 24.80295669,
#        23.35126223, 19.08373928, 19.89376541, 20.68267098, 16.17002298,
#        17.86657877, 14.23367899, 12.91170702, 20.46587536, 18.76011237,
#        14.01655237, 19.57500143, 10.68080563, 23.05028523, 25.12466985,
#        24.49057895, 18.55507372, 21.56429771])

# %%
X_test['pred'] = est.predict(X_test)
# Out:
# /Users/ngagnon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test['real'] = y_test
# Out:
# /Users/ngagnon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test['Diff'] =  abs(X_test['pred'] - X_test['real'])
# Out:
# /Users/ngagnon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test["Diff"].mean()
# Out:
# 5.2378607708127864

# %%
X_test['Diff'].std()
# Out:
# 3.7926490213222204

# %%
X_test[X_test['Diff']>20]
# Out:
#     Temperature  day  week  year  cloud_cover  snow  rain  \
# 70        52.82    1     7  2016         0.61   0.0   1.0
#
#     yesterday_visits_per_hour  year_2016  year_2017    ...      month_8  \
# 70                        3.5          1          0    ...            0
#
#     week_6  week_43  tempWeekend  holiday_week  prev_day  prev_week  \
# 70       0        0          0.0             1       5.5      6.875
#
#          pred  real       Diff
# 70  28.200314   4.5  23.700314
#
# [1 rows x 24 columns]

# %%
>15 = low
25>x>15 = medium
x>20 = high
# Out:
#   File "<ipython-input-649-9466c92e5d35>", line 1
#     >15 = low
#     ^
# SyntaxError: invalid syntax
