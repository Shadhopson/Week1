# %%
import pandas as pd
summed_by_date = pd.read_csv('../Data_And_Data_Creation/expanded_dummied_welcome_table_summed.csv')

# %%
from sklearn import feature_selection

# %%
summed_by_date = summed_by_date.dropna()

# %%
Keep = summed_by_date.columns.values[5:]

# %%
X = summed_by_date[Keep]

# %%
drop = X.columns.values[1:7]

# %%
drop
# Out:
# array(['from_11201', 'avg_visits_per_hour', 'avg_returns_per_hour',
#        'avg_new_per_hour', 'avg_from_11201_per_hour', 'ratio_11201'], dtype=object)

# %%
X = X.drop(drop, axis=1)

# %%
X = X.drop('given_temp', axis=1)

# %%
X =X.dropna()

# %%
X = X.reindex()

# %%
Y = summed_by_date.avg_visits_per_hour

# %% [markdown]
# # Getting the most important parts and using only those

# %%
from sklearn.ensemble import ExtraTreesRegressor

model = ExtraTreesRegressor()
model.fit(X, Y)
print(zip(X.columns.values,model.feature_importances_))
# Out:
# [('Temperature', 0.13571831772115509), ('day', 0.066188300368842629), ('week', 0.015011103105413964), ('month', 0.0097491460081837681), ('year', 0.017553780525140082), ('precipitation', 0.070550570947117891), ('cloud_cover', 0.041152620118485347), ('snow', 0.037916892602231259), ('rain', 0.0362194039661193), ('yesterday_visits_per_hour', 0.049442158713689635), ('year_2016', 0.025287216013797874), ('year_2017', 0.020299300965836643), ('year_2018', 0.0094039202053290191), ('day_1', 0.016309756051711526), ('day_2', 0.0), ('day_3', 0.013420529105025678), ('day_4', 0.0046493844006954485), ('day_5', 0.010347290007381911), ('day_6', 0.01693930015019875), ('month_2', 0.014076244436217777), ('month_3', 0.012595817559249803), ('month_4', 0.0087693016332511028), ('month_5', 0.0053410743247155942), ('month_6', 0.0069517033919628312), ('month_7', 0.0041224042013258862), ('month_8', 0.026722516859304303), ('month_9', 0.0060781752565127233), ('month_10', 0.0069158472100364493), ('month_11', 0.0027603997532467685), ('month_12', 0.014151763099425169), ('week_2', 0.0033542554272613669), ('week_3', 0.0016356164620593746), ('week_4', 0.0011069677417730121), ('week_5', 0.0012103681325230211), ('week_6', 0.0025403981808516567), ('week_7', 0.015023533986051007), ('week_8', 0.020970330145871189), ('week_9', 0.00073587161821638046), ('week_10', 0.0047649165816440776), ('week_11', 0.0032629767948428347), ('week_12', 0.0046061442980534825), ('week_13', 0.0050516756798384046), ('week_14', 0.0021182713806288142), ('week_15', 0.013103343844632635), ('week_16', 0.05463976798673921), ('week_17', 0.01179932152572543), ('week_18', 0.0021037870263926079), ('week_19', 0.0028674770384591224), ('week_20', 0.0015331571245065184), ('week_21', 0.0077802376424415138), ('week_22', 0.00621714624639454), ('week_23', 0.0081239540496057736), ('week_24', 0.0053621783171290908), ('week_25', 0.0073158941078211928), ('week_26', 0.00034884662208364836), ('week_27', 0.0029182199899204357), ('week_28', 0.0031022909957184991), ('week_29', 0.0033408178068829509), ('week_30', 0.012916680693742456), ('week_31', 0.003445473045106054), ('week_32', 0.0066868870071961168), ('week_33', 0.0019500964046129054), ('week_34', 0.0012625020119141634), ('week_35', 0.0025278566096088228), ('week_36', 0.017349720597774967), ('week_37', 0.0026297637453301559), ('week_38', 0.0066760777951680571), ('week_39', 0.004654391736902244), ('week_40', 0.0062971578463631482), ('week_41', 0.0061609322554025238), ('week_42', 0.0044903215722183771), ('week_43', 0.0045585826705355163), ('week_44', 0.0016201634517159706), ('week_45', 0.004266569792658023), ('week_46', 0.0040559206576282082), ('week_47', 0.00027579658007142094), ('week_48', 0.0018515605146180261), ('week_49', 0.0029249439835456635), ('week_50', 0.0016158519041402785), ('week_51', 0.00020074366807490643)]

# %%
important_features = []
for col, val in zip(X.columns.values,model.feature_importances_):
    if val > 0.025:
        important_features.append(col)

# %%
print important_features
# Out:
# ['Temperature', 'day', 'precipitation', 'cloud_cover', 'snow', 'rain', 'yesterday_visits_per_hour', 'year_2016', 'month_8', 'week_16']

# %%
from sklearn.model_selection import train_test_split

# %%
X2 = summed_by_date[important_features]

# %%
Y2 = summed_by_date.total_visitors

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.33, random_state=42)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.ensemble import RandomForestRegressor

forest_regr = RandomForestRegressor(max_depth=4, random_state=0)
forest_regr.fit(X_train, y_train.values.ravel())

#print(forest_regr.feature_importances_)

forest_y_pred = forest_regr.predict(X_test)

#print('Coefficients: \n', forest_regr.coef_)
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, forest_y_pred))
print('Variance score: %.2f' % r2_score(y_test, forest_y_pred))

plt.figure(figsize=(5,5))
plt.scatter(y_test, forest_y_pred, color='blue', linewidth=3)
plt.xlabel("Real Values")
plt.ylabel("Predicted Values")
plt.plot([0,200], [0,200])
plt.ylim(0,200)
plt.xlim(0,200)
plt.show()
# Out:
# Mean squared error: 1134.12
# Variance score: 0.41

# %% [markdown]
# # Prediction for the day

# %%
#['Temperature', 'day', 'precipitation', 'cloud_cover', 'snow', 'rain', 'yesterday_visits_per_hour', 'year_2016', 'month_8', 'week_16']
forest_regr.predict([63, 6, 0, 0, 0 ,0,7.75, 0, 0,0])
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([ 91.30315468])

# %%
from sklearn.ensemble import GradientBoostingRegressor

est = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=0, loss='ls').fit(X_train, y_train)

print("Mean squared error: %.2f"
      % mean_squared_error(y_test, est.predict(X_test)))
print('Variance score: %.2f' % r2_score(y_test, est.predict(X_test)))

plt.figure(figsize=(5,5))
plt.scatter(y_test, est.predict(X_test), color='blue', linewidth=3)
plt.xlabel('Real Values')
plt.ylabel('Predicted Values')
plt.plot([0,200], [0,200])
plt.ylim(0,200)
plt.xlim(0,200)
plt.show()
# Out:
# Mean squared error: 1132.18
# Variance score: 0.41

# %%
est.predict([63, 6, 0, 0, 0 ,0,7.75, 0, 0,0])
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([ 83.34343396])

# %%
test = feature_selection.SelectKBest( k=10)

# %%
fit = test.fit(X, Y)

# %%
fit
# Out:
# SelectKBest(k=10, score_func=<function f_classif at 0x0000000009CCC978>)

# %%
for name, val in zip(X.columns.values,fit.scores_):
    if val > 2.1:
        print name, val
# Out:
# day 2.36621839671
# precipitation 2.26120629143
# day_4 2.28369198226
# week_7 2.15928595098
# week_35 2.11214486201
# week_36 3.17211080828
# week_50 2.17734052517

# %%
features = fit.transform(X)

# %%
feature_names = X.columns.values

# %% [markdown]
# # Working on figuring out what are the best indicators for the amount of people visiting and only keeping those. Currently not doing it

# %%
corr_matrix = summed_by_date.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] < 0.1)]

# %%
to_drop
# Out:
# ['Temperature',
#  'from_11201',
#  'avg_returns_per_hour',
#  'avg_new_per_hour',
#  'avg_from_11201_per_hour',
#  'ratio_11201',
#  'day',
#  'week',
#  'month',
#  'year',
#  'precipitation',
#  'cloud_cover',
#  'snow',
#  'rain',
#  'yesterday_visits_per_hour',
#  'year_2016',
#  'year_2017',
#  'year_2018',
#  'day_1',
#  'day_2',
#  'day_3',
#  'day_4',
#  'day_5',
#  'day_6',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12',
#  'week_2',
#  'week_3',
#  'week_4',
#  'week_5',
#  'week_6',
#  'week_7',
#  'week_8',
#  'week_9',
#  'week_10',
#  'week_11',
#  'week_12',
#  'week_13',
#  'week_14',
#  'week_15',
#  'week_16',
#  'week_17',
#  'week_18',
#  'week_19',
#  'week_20',
#  'week_21',
#  'week_22',
#  'week_23',
#  'week_24',
#  'week_25',
#  'week_26',
#  'week_27',
#  'week_28',
#  'week_29',
#  'week_30',
#  'week_31',
#  'week_32',
#  'week_33',
#  'week_34',
#  'week_35',
#  'week_36',
#  'week_37',
#  'week_38',
#  'week_39',
#  'week_40',
#  'week_41',
#  'week_42',
#  'week_43',
#  'week_44',
#  'week_45',
#  'week_46',
#  'week_47',
#  'week_48',
#  'week_49',
#  'week_50',
#  'week_51']

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

train, test = train_test_split(summed_by_date, test_size=0.2)

Y_Train = train[['total_visitors']]
Y_Test = test[['total_visitors']]


drop_columns = ['Unnamed: 0','total_visitors','Unnamed: 0.1', 'given_temp','from_11201','avg_from_11201_per_hour','ratio_11201','total_returns', 'total_new','avg_visits_per_hour', 'avg_returns_per_hour', 'avg_new_per_hour']
train.drop(drop_columns, inplace=True, axis=1)
test.drop(drop_columns, inplace=True, axis=1)
train =  train['']

X_Train = train.fillna(0)
X_Test = test.fillna(0)

#Normalizing data
X_Test_norm  = StandardScaler().fit_transform(X_Test)
X_Train_norm  = StandardScaler().fit_transform(X_Train)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
summed_by_date.columns.values
# Out:
# array(['Unnamed: 0', 'Unnamed: 0.1', 'total_visitors', 'total_returns',
#        'total_new', 'Temperature', 'from_11201', 'avg_visits_per_hour',
#        'avg_returns_per_hour', 'avg_new_per_hour',
#        'avg_from_11201_per_hour', 'ratio_11201', 'day', 'week', 'month',
#        'year', 'given_temp', 'precipitation', 'cloud_cover', 'snow',
#        'rain', 'yesterday_visits_per_hour', 'year_2016', 'year_2017',
#        'year_2018', 'day_1', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6',
#        'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7',
#        'month_8', 'month_9', 'month_10', 'month_11', 'month_12', 'week_2',
#        'week_3', 'week_4', 'week_5', 'week_6', 'week_7', 'week_8',
#        'week_9', 'week_10', 'week_11', 'week_12', 'week_13', 'week_14',
#        'week_15', 'week_16', 'week_17', 'week_18', 'week_19', 'week_20',
#        'week_21', 'week_22', 'week_23', 'week_24', 'week_25', 'week_26',
#        'week_27', 'week_28', 'week_29', 'week_30', 'week_31', 'week_32',
#        'week_33', 'week_34', 'week_35', 'week_36', 'week_37', 'week_38',
#        'week_39', 'week_40', 'week_41', 'week_42', 'week_43', 'week_44',
#        'week_45', 'week_46', 'week_47', 'week_48', 'week_49', 'week_50',
#        'week_51'], dtype=object)

# %%
summed_by_date.corr().sort_values('total_visitors', ascending=False)
# Out:
#                            Unnamed: 0  total_visitors  total_returns  \
# total_visitors              -0.165570        1.000000       0.507907
# total_new                   -0.287275        0.943824       0.197827
# avg_new_per_hour            -0.322247        0.879432       0.148227
# avg_visits_per_hour         -0.152318        0.858992       0.534786
# from_11201                  -0.086697        0.627625       0.738432
# day                         -0.065961        0.600881       0.254290
# total_returns                0.264780        0.507907       1.000000
# day_6                       -0.022615        0.431781       0.237656
# day_5                       -0.023229        0.294336       0.072223
# Temperature                 -0.135947        0.231880      -0.075026
# avg_from_11201_per_hour     -0.035716        0.166973       0.518132
# week_16                     -0.033146        0.134428       0.026311
# yesterday_visits_per_hour   -0.150567        0.133984       0.059192
# month_4                     -0.076226        0.119002       0.087443
# avg_returns_per_hour         0.280236        0.113853       0.780220
# year_2016                   -0.559826        0.112520      -0.001190
# month_8                     -0.029659        0.095469      -0.054284
# week_31                      0.020541        0.079930       0.005491
# month_6                     -0.013889        0.075041      -0.038981
# week_8                      -0.009415        0.074091       0.111995
# week_36                      0.039215        0.070700       0.125203
# week_34                     -0.044582        0.070195      -0.040713
# week_15                     -0.036881        0.068942       0.006792
# week_33                      0.028011        0.063229       0.064046
# week_7                       0.029475        0.056686       0.037162
# week_25                      0.000467        0.050922      -0.043955
# week_23                      0.005796        0.050341       0.009473
# week_45                     -0.001548        0.048387       0.065042
# month_7                      0.005934        0.048261      -0.145950
# week_26                     -0.061143        0.044831      -0.035532
# ...                               ...             ...            ...
# week_13                      0.034198       -0.027942       0.041665
# week_47                     -0.065709       -0.030458      -0.031154
# week_19                     -0.021942       -0.035660       0.004190
# month_2                      0.026440       -0.035744       0.005949
# month_5                     -0.053939       -0.039112       0.013589
# week_14                     -0.049917       -0.039306      -0.000254
# week_2                       0.026510       -0.041102       0.036099
# week_21                     -0.025831       -0.042945      -0.107308
# week_3                       0.051259       -0.047635       0.014025
# week_44                     -0.005641       -0.048998      -0.028468
# week_48                      0.029709       -0.053151      -0.016299
# week_5                       0.020288       -0.057554      -0.017253
# day_2                       -0.081417       -0.058336      -0.106535
# week_43                      0.012553       -0.062999      -0.050122
# rain                         0.029927       -0.064788      -0.029404
# week_50                      0.016225       -0.064790      -0.048506
# week_49                      0.012131       -0.072686      -0.030694
# year_2017                    0.568141       -0.084856       0.077723
# week_51                     -0.023993       -0.085772      -0.079461
# year_2018                    0.518657       -0.109287       0.171722
# week_6                       0.005933       -0.135036      -0.100475
# month_12                     0.025040       -0.137568      -0.077464
# year                         0.924121       -0.155851       0.284309
# precipitation                0.004960       -0.159708      -0.132613
# Unnamed: 0                   1.000000       -0.165570       0.264780
# snow                         0.032859       -0.174625      -0.151548
# cloud_cover                  0.078311       -0.186341      -0.043114
# day_1                        0.114184       -0.358714      -0.099177
# day_3                       -0.035333       -0.366528      -0.188358
# avg_visits_per_hour                   1.000000              0.424175
# from_11201                            0.651862              0.537720
# day                                   0.235218             -0.281327
# total_returns                         0.534786              0.780220
# day_6                                 0.197898             -0.120083
# day_5                                 0.054925             -0.232269
# Temperature                           0.306314             -0.062343
# avg_from_11201_per_hour               0.495229              0.789954
# week_16                               0.130092              0.008703
# yesterday_visits_per_hour             0.201961              0.078636
# month_4                               0.124113              0.060612
# avg_returns_per_hour                  0.424175              1.000000
# year_2016                             0.143588              0.004028
# month_8                               0.170367             -0.038160
# week_31                               0.120948             -0.001886
# month_6                               0.087325             -0.051081
# week_8                                0.088693              0.102090
# week_36                               0.142436              0.155182
# week_34                               0.100865             -0.034207
# week_15                               0.098089              0.008703
# week_33                               0.098089              0.068707
# week_7                                0.064226              0.034943
# week_25                               0.051914             -0.058359
# week_23                               0.066940             -0.003529
# week_45                               0.060970              0.060911
# month_7                               0.049876             -0.138356
# week_26                               0.060377             -0.018104
# ...                                        ...                   ...
# week_13                              -0.026642              0.042038
# week_47                              -0.027544             -0.008857
# week_19                              -0.040437              0.009586
# month_2                              -0.046831              0.017252
# month_5                              -0.048883              0.020105
# week_14                              -0.065370             -0.012952
# week_2                               -0.041896              0.046568
# week_21                              -0.070335             -0.097880
# week_3                               -0.042027              0.034863
# week_44                              -0.077488             -0.037982
# week_48                              -0.085464             -0.025247
# week_5                               -0.077476             -0.010640
# day_2                                -0.048259             -0.099585
# week_43                              -0.075629             -0.029202
# rain                                 -0.079422             -0.010084
# week_50                              -0.093915             -0.055345
# week_49                              -0.091178             -0.016090
# year_2017                            -0.087329              0.084087
# week_51                              -0.093688             -0.054415
# year_2018                            -0.112096              0.173245
# week_6                               -0.157698             -0.070694
# month_12                             -0.183150             -0.074993
# year                                 -0.143090              0.296874
# precipitation                        -0.209404             -0.124231
# Unnamed: 0                           -0.152318              0.280236
# snow                                 -0.214511             -0.125082
# cloud_cover                          -0.217151             -0.013527
# day_1                                -0.141317              0.237097
# day_3                                -0.106857              0.147298
# ratio_11201                          -0.438876              0.285059
#
#                            avg_new_per_hour  avg_from_11201_per_hour  \
# total_visitors                     0.879432                 0.166973
# total_new                          0.945757                -0.000991
# avg_new_per_hour                   1.000000                 0.115795
# avg_visits_per_hour                0.857383                 0.495229
# from_11201                         0.431788                 0.747515
# day                                0.419851                -0.315433
# total_returns                      0.148227                 0.518132
# day_6                              0.288908                -0.149464
# day_5                              0.190397                -0.286602
# Temperature                        0.373420                -0.050705
# avg_from_11201_per_hour            0.115795                 1.000000
# week_16                            0.138215                 0.060300
# yesterday_visits_per_hour          0.179907                 0.110784
# month_4                            0.101857                 0.024299
# avg_returns_per_hour              -0.099540                 0.789954
# year_2016                          0.150807                 0.067754
# month_8                            0.207645                -0.005665
# week_31                            0.133191                 0.011737
# month_6                            0.123404                -0.060326
# week_8                             0.040495                 0.083910
# week_36                            0.068392                 0.109796
# week_34                            0.130571                 0.015473
# week_15                            0.102048                -0.000403
# week_33                            0.067890                 0.018275
# week_7                             0.050139                 0.123255
# week_25                            0.089490                -0.079785
# week_23                            0.075776                -0.017204
# week_45                            0.032590                 0.093920
# month_7                            0.137352                -0.150839
# week_26                            0.076808                -0.021971
# ...                                     ...                      ...
# week_13                           -0.051210                 0.022407
# week_47                           -0.025037                 0.043840
# week_19                           -0.048648                 0.036019
# month_2                           -0.060910                 0.029234
# month_5                           -0.066353                -0.016164
# week_14                           -0.066379                -0.030167
# week_2                            -0.072267                 0.048159
# week_21                           -0.021786                -0.151285
# week_3                            -0.065761                 0.031349
# week_44                           -0.063242                -0.013478
# week_48                           -0.079268                -0.034958
# week_5                            -0.078781                -0.073510
# day_2                              0.003782                -0.079046
# week_43                           -0.064410                -0.003205
# rain                              -0.082373                -0.040155
# week_50                           -0.073126                -0.110603
# week_49                           -0.090746                 0.001464
# year_2017                         -0.140005                -0.118867
# week_51                           -0.071743                -0.003570
# year_2018                         -0.220973                 0.080422
# week_6                            -0.133149                -0.074441
# month_12                          -0.159050                -0.093062
# year                              -0.323532                -0.011905
# precipitation                     -0.158787                -0.140873
# Unnamed: 0                        -0.322247                -0.035716
# snow                              -0.164142                -0.150626
# cloud_cover                       -0.231716                -0.050206
# day_1                             -0.290515                 0.211519
# day_3                             -0.201993                 0.230655
# ratio_11201                       -0.647624                 0.453476
#
#                              ...      week_42   week_43   week_44   week_45  \
# total_visitors               ...     0.039425 -0.062999 -0.048998  0.048387
# total_new                    ...     0.041032 -0.051419 -0.044691  0.030272
# avg_new_per_hour             ...     0.066609 -0.064410 -0.063242  0.032590
# avg_visits_per_hour          ...     0.069023 -0.075629 -0.077488  0.060970
# from_11201                   ...     0.025814 -0.027514 -0.001534  0.099653
# day                          ...     0.005388 -0.002295  0.013723  0.013723
# total_returns                ...     0.012858 -0.050122 -0.028468  0.065042
# day_6                        ...     0.014231 -0.019067  0.005407  0.005407
# day_5                        ...    -0.019067  0.014231  0.005407  0.005407
# Temperature                  ...     0.042498  0.021278  0.005284 -0.048645
# avg_from_11201_per_hour      ...     0.028547 -0.003205 -0.013478  0.093920
# week_16                      ...    -0.018910 -0.018910 -0.019854 -0.019854
# yesterday_visits_per_hour    ...     0.072961 -0.017640 -0.090637  0.024796
# month_4                      ...    -0.040099 -0.040099 -0.042100 -0.042100
# avg_returns_per_hour         ...     0.018253 -0.029202 -0.037982  0.060911
# year_2016                    ...    -0.001354 -0.001354 -0.012744 -0.012744
# month_8                      ...    -0.044970 -0.044970 -0.047215 -0.047215
# week_31                      ...    -0.018910 -0.018910 -0.019854 -0.019854
# month_6                      ...    -0.038161 -0.038161 -0.040066 -0.040066
# week_8                       ...    -0.021186 -0.021186 -0.022244 -0.022244
# week_36                      ...    -0.018910 -0.018910 -0.019854 -0.019854
# week_34                      ...    -0.022244 -0.022244 -0.023355 -0.023355
# week_15                      ...    -0.018910 -0.018910 -0.019854 -0.019854
# week_33                      ...    -0.018910 -0.018910 -0.019854 -0.019854
# week_7                       ...    -0.023258 -0.023258 -0.024419 -0.024419
# week_25                      ...    -0.018910 -0.018910 -0.019854 -0.019854
# from_11201                -0.054964
# day                       -0.044021
# total_returns             -0.079461
# day_6                     -0.031772
# day_5                     -0.031772
# Temperature               -0.116899
# avg_from_11201_per_hour   -0.003570
# week_16                   -0.015771
# yesterday_visits_per_hour -0.085097
# month_4                   -0.033443
# avg_returns_per_hour      -0.054415
# year_2016                 -0.029396
# month_8                   -0.037506
# week_31                   -0.015771
# month_6                   -0.031827
# week_8                    -0.017670
# week_36                   -0.015771
# week_34                   -0.018552
# week_15                   -0.015771
# week_33                   -0.015771
# week_7                    -0.019397
# week_25                   -0.015771
# week_23                   -0.014737
# week_45                   -0.018552
# month_7                   -0.032911
# week_26                   -0.011105
# ...                             ...
# week_13                   -0.018552
# week_47                   -0.012429
# week_19                   -0.015771
# month_2                   -0.039431
# month_5                   -0.034489
# week_14                   -0.014737
# week_2                    -0.018552
# week_21                   -0.016745
# week_3                    -0.017670
# week_44                   -0.018552
# week_48                   -0.017670
# week_5                    -0.019397
# day_2                     -0.007836
# week_43                   -0.017670
# rain                      -0.058780
# week_50                   -0.018552
# week_49                   -0.018552
# year_2017                 -0.026947
# week_51                    1.000000
# year_2018                 -0.040372
# week_6                    -0.019397
# month_12                   0.440658
# year                      -0.095370
# precipitation              0.018708
# Unnamed: 0                -0.023993
# snow                      -0.023211
# cloud_cover               -0.002060
# day_1                      0.018614
# day_3                      0.049703
# ratio_11201                0.106082
#
# [90 rows x 90 columns]

# %%
import seaborn as sns
# %matplotlib inline

# load the R package ISLR
#infert = com.importr("ISLR")

# load the Auto dataset
#auto_df = com.load_data('Auto')

# calculate the correlation matrix
corr = summed_by_date.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
X_Train.columns.values
# Out:
# array(['Temperature', 'day', 'week', 'month', 'year', 'precipitation',
#        'cloud_cover', 'snow', 'rain', 'yesterday_visits_per_hour',
#        'year_2016', 'year_2017', 'year_2018', 'day_1', 'day_2', 'day_3',
#        'day_4', 'day_5', 'day_6', 'month_2', 'month_3', 'month_4',
#        'month_5', 'month_6', 'month_7', 'month_8', 'month_9', 'month_10',
#        'month_11', 'month_12', 'week_2', 'week_3', 'week_4', 'week_5',
#        'week_6', 'week_7', 'week_8', 'week_9', 'week_10', 'week_11',
#        'week_12', 'week_13', 'week_14', 'week_15', 'week_16', 'week_17',
#        'week_18', 'week_19', 'week_20', 'week_21', 'week_22', 'week_23',
#        'week_24', 'week_25', 'week_26', 'week_27', 'week_28', 'week_29',
#        'week_30', 'week_31', 'week_32', 'week_33', 'week_34', 'week_35',
#        'week_36', 'week_37', 'week_38', 'week_39', 'week_40', 'week_41',
#        'week_42', 'week_43', 'week_44', 'week_45', 'week_46', 'week_47',
#        'week_48', 'week_49', 'week_50', 'week_51'], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.ensemble import RandomForestRegressor

forest_regr = RandomForestRegressor(max_depth=4, random_state=0)
forest_regr.fit(X_Train_norm, Y_Train.values.ravel())

print(forest_regr.feature_importances_)

forest_y_pred = forest_regr.predict(X_Test_norm)

#print('Coefficients: \n', forest_regr.coef_)
print("Mean squared error: %.2f"
      % mean_squared_error(Y_Test, forest_y_pred))
print('Variance score: %.2f' % r2_score(Y_Test, forest_y_pred))

plt.figure(figsize=(5,5))
plt.scatter(Y_Test, forest_y_pred, color='blue', linewidth=3)
plt.plot([0,200], [0,200])
plt.ylim(0,200)
plt.xlim(0,200)
plt.show()
# Out:
# [  1.41065884e-01   5.25429732e-01   1.49429734e-03   0.00000000e+00
#    1.12881626e-03   2.91114449e-02   5.99430371e-03   0.00000000e+00
#    0.00000000e+00   8.46579420e-02   1.67660877e-02   1.46761349e-03
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   4.91544970e-04   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   3.93723768e-03   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   2.64859060e-03   4.10930736e-04
#    2.12512536e-03   0.00000000e+00   4.91405412e-04   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   2.85618070e-03
#    1.67957580e-01   4.16076598e-03   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   4.54487285e-04   3.19968312e-03
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    3.45696378e-03   0.00000000e+00   6.93383482e-04   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00]
# Mean squared error: 941.49
# Variance score: 0.17

# %%
from sklearn.ensemble import GradientBoostingRegressor

est = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=0, loss='ls').fit(X_Train_norm, Y_Train)

print("Mean squared error: %.2f"
      % mean_squared_error(Y_Test, est.predict(X_Test_norm)))
print('Variance score: %.2f' % r2_score(Y_Test, est.predict(X_Test_norm)))

plt.figure(figsize=(5,5))
plt.scatter(Y_Test, est.predict(X_Test_norm), color='blue', linewidth=3)
plt.plot([0,200], [0,200])
plt.ylim(0,200)
plt.xlim(0,200)
plt.show()
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean squared error: 959.38
# Variance score: 0.16

# %%
print(forest_regr.feature_importances_)
# Out:
# [  1.42806623e-01   5.18168508e-01   1.34932075e-02   7.57981214e-03
#    2.60912800e-04   3.28098314e-02   2.52145953e-02   1.91904583e-03
#    1.86521472e-03   8.39650327e-02   3.57125647e-03   1.16160011e-03
#    2.62454623e-04   0.00000000e+00   1.82772562e-05   0.00000000e+00
#    0.00000000e+00   6.67207769e-04   0.00000000e+00   2.00076960e-03
#    0.00000000e+00   5.79025932e-05   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    1.01374033e-03   0.00000000e+00   1.33287959e-04   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   6.53549816e-03   2.21994699e-03
#    6.87673155e-04   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   1.43729822e-01
#    4.43819488e-03   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   1.78922953e-03
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   2.88244802e-03   0.00000000e+00
#    7.47907460e-04   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00]

# %%
print est.feature_importances_
# Out:
# [  1.38694753e-01   1.33470212e-01   4.70591429e-02   6.80948056e-03
#    2.75942808e-03   1.14436942e-01   6.81723067e-02   1.64236498e-04
#    1.59498963e-03   1.47102140e-01   2.62145311e-02   1.13404928e-04
#    5.29684841e-03   0.00000000e+00   2.08686680e-04   8.82733874e-03
#    9.11152288e-03   1.29419342e-02   1.92174818e-03   1.06295995e-02
#    0.00000000e+00   2.09608119e-02   0.00000000e+00   1.30057409e-04
#    1.43745985e-03   3.62816166e-03   1.80391259e-03   2.00930795e-09
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.08641303e-02   2.08941245e-02   3.01076337e-03
#    2.88711147e-05   1.17919948e-04   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.69671106e-02   4.71825438e-03   8.18667813e-02
#    4.11254899e-03   2.94780804e-03   2.43319816e-03   0.00000000e+00
#    3.63468075e-03   0.00000000e+00   5.71506222e-03   9.33429922e-03
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    1.42374600e-03   2.81492059e-03   3.98490454e-04   1.07286734e-04
#    4.34131462e-03   0.00000000e+00   6.44767373e-03   1.01748560e-02
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   4.22225884e-03
#    0.00000000e+00   6.82844620e-03   0.00000000e+00   5.97147549e-03
#    1.47838855e-02   9.61022727e-03   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   2.74021390e-03   0.00000000e+00]
