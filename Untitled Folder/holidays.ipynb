# %%
import pandas as pd

# %%
hdDf = pd.read_csv('usholidays.csv')

# %%
hdDf['Date'] = pd.to_datetime(hdDf['Date'])

# %%
hdDf['week'] = hdDf['Date'].dt.week

# %%
hdDf['month'] = hdDf['Date'].dt.month

# %%
hdDf['year'] = hdDf['Date'].dt.year

# %%
hdDf['day'] = hdDf['Date'].dt.weekday

# %%
holidays = ["New Year's Day", "Christmas Day", "Thanksgiving Day"]

# %%
hdDf = hdDf[hdDf['Holiday'].isin(holidays)]

# %%
hdDf = hdDf[hdDf['year'].isin([2015,2016,2017,2018,2019])]

# %%
hdDf[hdDf['Holiday'] == "Thanksgiving Day"]
# Out:
#     Unnamed: 0       Date           Holiday  week  month  year  day
# 48          48 2015-11-26  Thanksgiving Day    48     11  2015    3
# 58          58 2016-11-24  Thanksgiving Day    47     11  2016    3
# 68          68 2017-11-23  Thanksgiving Day    47     11  2017    3
# 78          78 2018-11-22  Thanksgiving Day    47     11  2018    3
# 88          88 2019-11-28  Thanksgiving Day    48     11  2019    3

# %%
df =pd.read_csv("../Data_And_Data_Creation/expanded_dummied_welcome_table_summed.csv")

# %%
diff = pd.Timedelta('2 days')

# %%
diff2 = pd.Timedelta('3 days')

# %%
sun = hdDf[hdDf['Holiday'] == "Thanksgiving Day"]['Date'] + diff

# %%
sat = hdDf[hdDf['Holiday'] == "Thanksgiving Day"]['Date'] + diff2

# %%
thanks_lis = []
for val in sun:
    thanks_lis.append(val)
for val in sat:
    thanks_lis.append(val)

# %%
thanks_lis
# Out:
# [Timestamp('2015-11-28 00:00:00'),
#  Timestamp('2016-11-26 00:00:00'),
#  Timestamp('2017-11-25 00:00:00'),
#  Timestamp('2018-11-24 00:00:00'),
#  Timestamp('2019-11-30 00:00:00'),
#  Timestamp('2015-11-29 00:00:00'),
#  Timestamp('2016-11-27 00:00:00'),
#  Timestamp('2017-11-26 00:00:00'),
#  Timestamp('2018-11-25 00:00:00'),
#  Timestamp('2019-12-01 00:00:00')]

# %%
df[df.month == 11]
# Out:
#      Unnamed: 0 Unnamed: 0.1  total_visitors  total_new  total_returns  \
# 28           28   2015-11-01              66       53.0           13.0
# 29           29   2015-11-05              49       29.0           20.0
# 30           30   2015-11-07             121      108.0           13.0
# 31           31   2015-11-08              94       72.0           22.0
# 32           32   2015-11-12               9        6.0            3.0
# 33           33   2015-11-14              75       62.0           13.0
# 34           34   2015-11-15             110      102.0            8.0
# 35           35   2015-11-19              30       18.0           12.0
# 36           36   2015-11-21              83       62.0           21.0
# 37           37   2015-11-22              56       43.0           13.0
# 38           38   2015-11-28              67       53.0           14.0
# 39           39   2015-11-29              93       75.0           18.0
# 217         217   2016-11-01              38        5.0           33.0
# 218         218   2016-11-03              18        5.0           13.0
# 219         219   2016-11-05              79       61.0           18.0
# 220         220   2016-11-06              87       35.0           52.0
# 221         221   2016-11-08              64       22.0           42.0
# 222         222   2016-11-10              29        6.0           23.0
# 223         223   2016-11-12              80       54.0           26.0
# 224         224   2016-11-13             114       76.0           38.0
# 225         225   2016-11-15              34       10.0           24.0
# 226         226   2016-11-17              27        7.0           20.0
# 227         227   2016-11-19             128       74.0           54.0
# 228         228   2016-11-20              11        6.0            5.0
# 229         229   2016-11-22              24        8.0           16.0
# 230         230   2016-11-29               9        0.0            9.0
# 408         408   2017-11-02              20        9.0           11.0
# 409         409   2017-11-04              54       28.0           26.0
# 410         410   2017-11-05              50       26.0           24.0
# 411         411   2017-11-07              20        1.0           19.0
# 412         412   2017-11-09              32       17.0           15.0
# 413         413   2017-11-11              48       33.0           15.0
# 414         414   2017-11-12              87       24.0           63.0
# 415         415   2017-11-14              38        5.0           33.0
# 416         416   2017-11-16              25        8.0           17.0
# 417         417   2017-11-18              57       20.0           37.0
# 418         418   2017-11-19              91       49.0           42.0
# 419         419   2017-11-21              29        2.0           27.0
# 420         420   2017-11-28              26        8.0           18.0
# 421         421   2017-11-30              26        0.0           26.0
# 603         603   2018-11-01              23       10.0           13.0
# 604         604   2018-11-03              71       40.0           31.0
# 605         605   2018-11-04              87       33.0           54.0
# 606         606   2018-11-06               6        0.0            6.0
# 607         607   2018-11-08              21        5.0           16.0
# 608         608   2018-11-10              68       52.0           16.0
# 609         609   2018-11-11              61       23.0           38.0
# 610         610   2018-11-13              16        2.0           14.0
# 611         611   2018-11-15               5        0.0            5.0
# 612         612   2018-11-17              61       35.0           26.0
# 613         613   2018-11-18              54       22.0           32.0
# 614         614   2018-11-20              29       14.0           15.0
# 615         615   2018-11-27              21        1.0           20.0
# 616         616   2018-11-29              28        4.0           24.0
#
#      from_11201  Temperature  avg_visits_per_hour  avg_returns_per_hour  \
# 28          NaN        63.55                16.50                  3.25
# 29          NaN        67.31                24.50                 10.00
# 30          NaN        69.88                30.25                  3.25
# 31          NaN        57.37                23.50                  5.50
# 32          NaN        59.21                 4.50                  1.50
# 33          NaN        48.83                18.75                  3.25
# 34          NaN        58.36                27.50                  2.00
# 35          NaN        62.85                15.00                  6.00
# 36          NaN        50.03                20.75                  5.25
# 37          NaN        53.93                14.00                  3.25
# 38          NaN        59.95                16.75                  3.50
# 39          NaN        49.05                23.25                  4.50
# 217        36.0        58.39                19.00                 16.50
# 218        13.0        71.09                 9.00                  6.50
# 219        20.0        61.98                19.75                  4.50
# 220        55.0        57.18                21.75                 13.00
# 221        48.0        67.15                32.00                 21.00
# 222        25.0        56.13                14.50                 11.50
# 223        31.0        50.80                20.00                  6.50
# 224        42.0        60.13                28.50                  9.50
# 225        32.0        54.93                17.00                 12.00
# 226        19.0        61.59                13.50                 10.00
# 227        56.0        59.10                32.00                 13.50
# 228         5.0        41.87                 2.75                  1.25
# 229        17.0        41.15                12.00                  8.00
# 230         9.0        59.18                 4.50                  4.50
# 408         9.0        70.45                10.00                  5.50
# 409        27.0        56.21                13.50                  6.50
# 410        19.0        61.18                12.50                  6.00
# 411        19.0        48.44                10.00                  9.50
# 412        18.0        53.59                16.00                  7.50
# 413        19.0        37.68                12.00                  3.75
# 414        62.0        46.05                21.75                 15.75
# 415        32.0        46.13                19.00                 16.50
# 416        17.0        56.32                12.50                  8.50
# 417        30.0        52.45                14.25                  9.25
# 418        48.0        58.14                22.75                 10.50
# 419        29.0        57.38                14.50                 13.50
# 420        24.0        51.92                13.00                  9.00
# 421        26.0        50.76                13.00                 13.00
# 603        16.0        69.52                11.50                  6.50
# 604        30.0        64.98                17.75                  7.75
# 605        51.0        55.48                21.75                 13.50
# 220        0       0        0        0        0
# 221        0       0        0        0        0
# 222        0       0        0        0        0
# 223        0       0        0        0        0
# 224        0       0        0        0        0
# 225        0       0        0        0        0
# 226        0       0        0        0        0
# 227        0       0        0        0        0
# 228        0       0        0        0        0
# 229        1       0        0        0        0
# 230        0       1        0        0        0
# 408        0       0        0        0        0
# 409        0       0        0        0        0
# 410        0       0        0        0        0
# 411        0       0        0        0        0
# 412        0       0        0        0        0
# 413        0       0        0        0        0
# 414        0       0        0        0        0
# 415        0       0        0        0        0
# 416        0       0        0        0        0
# 417        0       0        0        0        0
# 418        0       0        0        0        0
# 419        1       0        0        0        0
# 420        0       1        0        0        0
# 421        0       1        0        0        0
# 603        0       0        0        0        0
# 604        0       0        0        0        0
# 605        0       0        0        0        0
# 606        0       0        0        0        0
# 607        0       0        0        0        0
# 608        0       0        0        0        0
# 609        0       0        0        0        0
# 610        0       0        0        0        0
# 611        0       0        0        0        0
# 612        0       0        0        0        0
# 613        0       0        0        0        0
# 614        1       0        0        0        0
# 615        0       1        0        0        0
# 616        0       1        0        0        0
#
# [54 rows x 93 columns]

# %%
df['Date'] =  pd.to_datetime(df['Unnamed: 0.1'])

# %%
thanksgiving = df[df['Date'].isin(thanks_lis)][['Date','total_visitors']]

# %%
thanksgiving
# Out:
#          Date  total_visitors
# 38 2015-11-28              67
# 39 2015-11-29              93

# %%
df[(df.month == 11) &(df.year == 2015)& (df.day > 4)]['total_visitors'].mean()
# Out:
# 85.0

# %%
thanksgiving = thanksgiving.append({'Date': "Weekend After Thanksgiving Average", "total_visitors":thanksgiving['total_visitors'].mean()}, ignore_index=True)

# %%
thanksgiving
# Out:
#                                  Date  total_visitors
# 0                 2015-11-28 00:00:00            67.0
# 1                 2015-11-29 00:00:00            93.0
# 2  Weekend After Thanksgiving Average            80.0

# %%
christmas = hdDf[hdDf['Holiday'] == "Christmas Day"]

# %%
christmas['eve'] = christmas['Date'] -  pd.Timedelta('1 days')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
christmas
# Out:
#     Unnamed: 0       Date        Holiday  week  month  year  day        eve
# 49          49 2015-12-25  Christmas Day    52     12  2015    4 2015-12-24
# 59          59 2016-12-26  Christmas Day    52     12  2016    0 2016-12-25
# 69          69 2017-12-25  Christmas Day    52     12  2017    0 2017-12-24
# 79          79 2018-12-25  Christmas Day    52     12  2018    1 2018-12-24
# 89          89 2019-12-25  Christmas Day    52     12  2019    2 2019-12-24

# %%
christmas['eve'].values
# Out:
# array(['2015-12-24T00:00:00.000000000', '2016-12-25T00:00:00.000000000',
#        '2017-12-24T00:00:00.000000000', '2018-12-24T00:00:00.000000000',
#        '2019-12-24T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
chris_list = []

for i in range(1,8):
    cat = christmas['eve'].values - pd.Timedelta(str(i)+ ' days')
    for val in cat:
        chris_list.append(val)

# %%
christmas = df[df['Date'].isin(chris_list)][['Date','total_visitors']]

# %%
christmas['Day'] =  christmas['Date'].dt.weekday

# %%
christmas = christmas.append({'Date': "Average For Week Before Christmas Eve", "total_visitors":christmas['total_visitors'].mean(), 'Day': 'null'}, ignore_index=True)

# %%
christmas = christmas.append({'Date': "Average For Weekend Before Christmas Eve", "total_visitors":christmas[christmas['Day'] > 4]['total_visitors'].mean(), 'Day': 'null'}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-915dfcd6de24> in <module>
# ----> 1 christmas = christmas.append({'Date': "Average For Weekend Before Christmas Eve", "total_visitors":christmas[christmas['Day'] > 4]['total_visitors'].mean(), 'Day': 'null'}, ignore_index=True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
christmas.replace([3, 5, 6, 1], ['Thursday', 'Saturday', 'Sunday', 'Tuesday'])
# Out:
#                                      Date  total_visitors       Day
# 0                     2015-12-17 00:00:00       14.000000  Thursday
# 1                     2015-12-19 00:00:00       29.000000  Saturday
# 2                     2015-12-20 00:00:00       79.000000    Sunday
# 3                     2016-12-18 00:00:00       51.000000    Sunday
# 4                     2016-12-20 00:00:00       13.000000   Tuesday
# 5                     2016-12-22 00:00:00       39.000000  Thursday
# 6                     2017-12-17 00:00:00       29.000000    Sunday
# 7                     2017-12-19 00:00:00       21.000000   Tuesday
# 8                     2017-12-21 00:00:00       10.000000  Thursday
# 9                     2018-12-18 00:00:00       12.000000   Tuesday
# 10                    2018-12-20 00:00:00       17.000000  Thursday
# 11  Average For Week Before Christmas Eve       28.545455      null

# %%
newYear = hdDf[hdDf['Holiday'] == "New Year's Day"]

# %%
ny_ls = []
for val in newYear['Date']:
    for i in range(1, 8):
        ny_ls.append(val + pd.Timedelta(str(i) + " days"))

# %%
new_years = df[df['Date'].isin(ny_ls)][['Date', 'total_visitors', 'day']]

# %%
new_years = new_years.append({"Date": "Week After New Years Average:", "total_visitors": new_years['total_visitors'].mean(), 'day':'null'}, ignore_index = True)

# %%
new_years= new_years.append({"Date": "Weekend After New Years Average:", "total_visitors": new_years[new_years['day'] > 4]['total_visitors'].mean(), 'day':'null'}, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-de23e6f806cc> in <module>
# ----> 1 new_years= new_years.append({"Date": "Weekend After New Years Average:", "total_visitors": new_years[new_years['day'] > 4]['total_visitors'].mean(), 'day':'null'}, ignore_index = True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
new_years =new_years.replace({1: "Tuesday", 3:"Thursday", 5:"Saturday", 6:"Sunday"})

# %%
new_years
# Out:
#                              Date  total_visitors       day
# 0             2016-01-07 00:00:00       20.000000  Thursday
# 1             2017-01-03 00:00:00       11.000000   Tuesday
# 2             2017-01-05 00:00:00       15.000000  Thursday
# 3             2017-01-07 00:00:00       15.000000  Saturday
# 4             2017-01-08 00:00:00       11.000000    Sunday
# 5             2018-01-02 00:00:00       20.000000   Tuesday
# 6             2018-01-06 00:00:00       14.000000  Saturday
# 7             2018-01-07 00:00:00       13.000000    Sunday
# 8             2019-01-03 00:00:00       31.000000  Thursday
# 9             2019-01-05 00:00:00       22.000000  Saturday
# 10            2019-01-06 00:00:00       92.000000    Sunday
# 11            2019-01-08 00:00:00       40.000000   Tuesday
# 12  Week After New Years Average:       25.333333      null

# %%
df[['month', 'total_visitors']].groupby("month").mean()
# Out:
#        total_visitors
# month
# 1           40.725806
# 2           49.500000
# 3           53.657143
# 4           63.852941
# 5           46.661972
# 6           64.042553
# 7           61.333333
# 8           64.677966
# 9           58.900000
# 10          52.063492
# 11          50.907407
# 12          32.956522

# %%
df[df['day']>4][['month', 'total_visitors']].groupby("month").mean()
# Out:
#        total_visitors
# month
# 1           57.100000
# 2           68.218750
# 3           77.200000
# 4           89.685714
# 5           70.787879
# 6           90.920000
# 7           85.222222
# 8           88.428571
# 9           79.812500
# 10          71.705882
# 11          76.037037
# 12          44.291667
