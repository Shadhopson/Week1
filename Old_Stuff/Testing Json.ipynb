# %%
import json

# load from file:
with open('past_weather.json', 'r') as f:
    try:
        data = json.load(f)
    # if the file is empty the ValueError will be thrown
    except ValueError:
        data = {}
print data
# Out:
# {u'2015-11-19': [{u'apparentTemperatureMinTime': 1447912800, u'precipType': u'rain', u'cloudCover': 0.92, u'precipIntensityMaxTime': 1447977600, u'temperatureMin': 57.93, u'summary': u'Rain in the afternoon and evening.', u'dewPoint': 56.29, u'apparentTemperatureMax': 63, u'temperatureMax': 63, u'temperatureMaxTime': 1447988400, u'windBearing': 144, u'moonPhase': 0.27, u'temperatureMinTime': 1447912800, u'visibility': 6.99, u'sunsetTime': 1447969017, u'pressure': 1020.43, u'apparentTemperatureMin': 57.93, u'precipIntensityMax': 0.1631, u'icon': u'rain', u'apparentTemperatureMaxTime': 1447988400, u'humidity': 0.86, u'windSpeed': 15.24, u'time': 1447909200, u'precipIntensity': 0.0284, u'sunriseTime': 1447933712, u'precipProbability': 0.86}], u'2015-11-18': [{u'apparentTemperatureMinTime': 1447830000, u'temperatureMinTime': 1447830000, u'cloudCover': 0.82, u'temperatureMin': 46.65, u'summary': u'Partly cloudy in the morning.', u'dewPoint': 42.62, u'apparentTemperatureMax': 58, u'tempera
# ...

# %%
print data['2015-11-19'][0]
# Out:
# {u'apparentTemperatureMinTime': 1447912800, u'precipType': u'rain', u'cloudCover': 0.92, u'precipIntensityMaxTime': 1447977600, u'temperatureMin': 57.93, u'summary': u'Rain in the afternoon and evening.', u'dewPoint': 56.29, u'apparentTemperatureMax': 63, u'temperatureMax': 63, u'temperatureMaxTime': 1447988400, u'windBearing': 144, u'moonPhase': 0.27, u'temperatureMinTime': 1447912800, u'visibility': 6.99, u'sunsetTime': 1447969017, u'pressure': 1020.43, u'apparentTemperatureMin': 57.93, u'precipIntensityMax': 0.1631, u'icon': u'rain', u'apparentTemperatureMaxTime': 1447988400, u'humidity': 0.86, u'windSpeed': 15.24, u'time': 1447909200, u'precipIntensity': 0.0284, u'sunriseTime': 1447933712, u'precipProbability': 0.86}
